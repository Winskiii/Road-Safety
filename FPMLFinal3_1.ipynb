# %%
import pandas as pd

df = pd.read_csv('train_road_safety.csv')

df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46649 entries, 0 to 46648
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   status                              44293 non-null  object
#  1   collision_index                     46649 non-null  object
#  2   collision_year                      44261 non-null  float64
#  3   collision_reference                 44343 non-null  object
#  4   vehicle_reference                   46649 non-null  float64
#  5   casualty_reference                  46649 non-null  float64
#  6   casualty_class                      46649 non-null  int64
#  7   sex_of_casualty                     44319 non-null  float64
#  8   age_of_casualty                     46649 non-null  int64
#  9   age_band_of_casualty                46649 non-null  int64
#  10  pedestrian_location                 46649 non-null  float64
#  11  pedestrian_movement                 46649 non-null  int64
#  12  car_passenger                       46649 non-null  int64
#  13  bus_or_coach_passenger              46649 non-null  int64
#  14  pedestrian_road_maintenance_worker  44314 non-null  float64
#  15  casualty_type                       46649 non-null  int64
#  16  casualty_home_area_type             44292 non-null  float64
#  17  casualty_imd_decile                 46649 non-null  int64
#  18  lsoa_of_casualty                    46649 non-null  object
#  19  enhanced_casualty_severity          46649 non-null  int64
#  20  casualty_severity                   46649 non-null  int64
# dtypes: float64(7), int64(10), object(4)
# memory usage: 7.5+ MB
#        collision_year  vehicle_reference  casualty_reference  casualty_class  \
# count         44261.0       46649.000000        46649.000000    46649.000000
# mean           2024.0           1.455616            1.353898        1.485520
# std               0.0           1.444068            1.267332        0.732898
# min            2024.0           0.462251            0.595506        1.000000
# 25%            2024.0           1.000000            1.000000        1.000000
# 50%            2024.0           1.000000            1.000000        1.000000
# 75%            2024.0           2.000000            1.000000        2.000000
# max            2024.0         203.000000          202.000000        3.000000
#
#        sex_of_casualty  age_of_casualty  age_band_of_casualty  \
# count     44319.000000     46649.000000          46649.000000
# mean          1.366637        37.102982              6.326502
# std           0.577406        19.826586              2.493991
# min          -1.000000        -1.000000             -1.000000
# 25%           1.000000        22.000000              5.000000
# 50%           1.000000        34.000000              6.000000
# 75%           2.000000        51.000000              8.000000
# max           9.000000       120.000000             11.000000
#
#        pedestrian_location  pedestrian_movement  car_passenger  \
# count         46649.000000         46649.000000   46649.000000
# mean              0.795227             0.657442       0.196574
# std               2.196648             2.047634       0.647400
# min              -1.000000            -1.000000      -1.000000
# 25%               0.000000             0.000000       0.000000
# 50%               0.000000             0.000000       0.000000
# 75%               0.000000             0.000000       0.000000
# max              10.334651             9.000000       9.000000
#
#        bus_or_coach_passenger  pedestrian_road_maintenance_worker  \
# count            46649.000000                        44314.000000
# mean                 0.058072                            0.031548
# std                  0.465305                            0.286917
# min                 -1.000000                           -1.000000
# 25%                  0.000000                            0.000000
# 50%                  0.000000                            0.000000
# 75%                  0.000000                            0.000000
# max                  9.000000                            2.000000
#
#        casualty_type  casualty_home_area_type  casualty_imd_decile  \
# count   46649.000000             44292.000000         46649.000000
# mean        9.314112                 0.993227             4.132307
# std        15.842578                 0.979042             3.286280
# min        -1.000000                -1.000000            -1.000000
# 25%         2.000000                 1.000000             2.000000
# 50%         9.000000                 1.000000             4.000000
# 75%         9.000000                 1.000000             7.000000
# max        98.000000                 3.000000            10.000000
#
#        enhanced_casualty_severity  casualty_severity
# count                46649.000000       46649.000000
# mean                     1.582220           2.882741
# std                      2.273239           0.362108
# min                     -1.000000           1.000000
# 25%                     -1.000000           3.000000
# 50%                      3.000000           3.000000
# 75%                      3.000000           3.000000
# max                      7.000000           3.000000

# %%
import numpy as np

df.drop(columns=["status", "collision_year", "collision_reference","lsoa_of_casualty","age_band_of_casualty","collision_index",], inplace=True)

#imputasi dengan modus
sex_mode = df["sex_of_casualty"].mode()[0]
df["sex_of_casualty"].fillna(sex_mode, inplace=True)

#imputasi dengan modus
worker_mode = df["pedestrian_road_maintenance_worker"].mode()[0]
df["pedestrian_road_maintenance_worker"].fillna(worker_mode, inplace=True)

#imputasi dengan modus
area_type_mode = df["casualty_home_area_type"].mode()[0]
df["casualty_home_area_type"].fillna(area_type_mode, inplace=True)

# Identifikasi nilai absurd
mask_invalid = df['pedestrian_location'] > 100

# Ganti nilai absurd dengan 0 atau NaN jika tidak bisa dipercaya
df.loc[mask_invalid, 'pedestrian_location'] = 0

# Set pedestrian_location = 0 bila pedestrian_movement == 0
df.loc[df['pedestrian_movement'] == 0, 'pedestrian_location'] = 0

# Gabungkan sebagai string lalu encode dan drop kolom aslinya
df['pedestrian_context'] = df['pedestrian_location'].astype(str) + "_" + df['pedestrian_movement'].astype(str)
df.drop(columns=['pedestrian_location', 'pedestrian_movement'], inplace=True)

# Ganti nilai tidak valid dengan NaN
df['casualty_home_area_type'].replace([-10, 10, 20, 30], np.nan, inplace=True)
df['casualty_imd_decile'].replace(-1, np.nan, inplace=True)

# Imputasi NaN dengan modus
home_mode = df['casualty_home_area_type'].mode()[0]
imd_mode = df['casualty_imd_decile'].mode()[0]

df['casualty_home_area_type'].fillna(home_mode, inplace=True)
df['casualty_imd_decile'].fillna(imd_mode, inplace=True)


missing = df.isnull().sum()
print(missing[missing > 0])

df.isnull().sum()
# Out:
# Series([], dtype: int64)
# /tmp/ipython-input-2-3428061107.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["sex_of_casualty"].fillna(sex_mode, inplace=True)
# /tmp/ipython-input-2-3428061107.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["pedestrian_road_maintenance_worker"].fillna(worker_mode, inplace=True)
# /tmp/ipython-input-2-3428061107.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["casualty_home_area_type"].fillna(area_type_mode, inplace=True)
# /tmp/ipython-input-2-3428061107.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['casualty_home_area_type'].replace([-10, 10, 20, 30], np.nan, inplace=True)
# /tmp/ipython-input-2-3428061107.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['casualty_imd_decile'].replace(-1, np.nan, inplace=True)
# /tmp/ipython-input-2-3428061107.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['casualty_home_area_type'].fillna(home_mode, inplace=True)
# vehicle_reference                     0
# casualty_reference                    0
# casualty_class                        0
# sex_of_casualty                       0
# age_of_casualty                       0
# car_passenger                         0
# bus_or_coach_passenger                0
# pedestrian_road_maintenance_worker    0
# casualty_type                         0
# casualty_home_area_type               0
# casualty_imd_decile                   0
# enhanced_casualty_severity            0
# casualty_severity                     0
# pedestrian_context                    0
# dtype: int64

# %%
#split dan smote
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder

le_context = LabelEncoder()
df['pedestrian_context'] = le_context.fit_transform(df['pedestrian_context'].astype(str))

# Pisahkan fitur dan target
X = df.drop(columns=['casualty_severity'])  # semua kolom kecuali target
y = df['casualty_severity'] - 1  # ubah label jadi 0, 1, 2

X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42
)

smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder

X = df.drop(columns=["casualty_severity"])
y = df["casualty_severity"] - 1  # klasifikasi 0, 1, 2

label_encoders = {}
for col in X.select_dtypes(include="object").columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))
    label_encoders[col] = le

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

from sklearn.ensemble import (
    RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier,
    BaggingClassifier, VotingClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier
)
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from xgboost import XGBClassifier

models = [
    ("LogisticRegression", LogisticRegression(max_iter=1000, random_state=42)),
    ("KNN", KNeighborsClassifier(n_neighbors=5)),
    ("GaussianNB", GaussianNB()),
    ("Decision Tree", DecisionTreeClassifier(random_state=42)),
    ("Random Forest", RandomForestClassifier(random_state=42)),
    ("ExtraTrees", ExtraTreesClassifier(random_state=42)),
    ("Bagging", BaggingClassifier(random_state=42)),
    ("AdaBoost", AdaBoostClassifier(random_state=42)),
    ("GradientBoost", GradientBoostingClassifier(random_state=42)),
    ("HistGradientBoost", HistGradientBoostingClassifier(random_state=42)),
    ("XGBoost", XGBClassifier(use_label_encoder=False, eval_metric="mlogloss", random_state=42)),
    ("LDA", LinearDiscriminantAnalysis()),
    ("QDA", QuadraticDiscriminantAnalysis())
]

# Tambahkan Voting Classifier
voting = VotingClassifier(estimators=[
    ("xgb", XGBClassifier(use_label_encoder=False, eval_metric="mlogloss", random_state=42)),
    ("gb", GradientBoostingClassifier(random_state=42)),
    ("rf", RandomForestClassifier(random_state=42))
], voting="soft")
models.append(("Voting", voting))

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
results = []

for name, model in models:
    try:
        scores = cross_val_score(model, X_train, y_train, scoring="accuracy", cv=cv, n_jobs=-1)
        results.append((name, scores.mean(), scores.std()))
    except Exception as e:
        print(f"{name} error: {e}")

results_df = pd.DataFrame(results, columns=["Algorithm", "CrossValMeans", "CrossValStd"])
results_df = results_df.sort_values(by="CrossValMeans", ascending=False).reset_index(drop=True)

print("Fitur yang digunakan:")
print(X.columns.tolist())
print(results_df)
# Out:
# Fitur yang digunakan:
# ['vehicle_reference', 'casualty_reference', 'casualty_class', 'sex_of_casualty', 'age_of_casualty', 'car_passenger', 'bus_or_coach_passenger', 'pedestrian_road_maintenance_worker', 'casualty_type', 'casualty_home_area_type', 'casualty_imd_decile', 'enhanced_casualty_severity', 'pedestrian_context']
#              Algorithm  CrossValMeans  CrossValStd
# 0        GradientBoost       0.966693     0.000865
# 1               Voting       0.966532     0.000739
# 2    HistGradientBoost       0.966505     0.001107
# 3              XGBoost       0.965755     0.001049
# 4        Random Forest       0.960342     0.001219
# 5             AdaBoost       0.956376     0.000952
# 6              Bagging       0.954018     0.001248
# 7           ExtraTrees       0.953429     0.001458
# 8                  KNN       0.937753     0.001399
# 9        Decision Tree       0.934725     0.002031
# 10  LogisticRegression       0.927758     0.001129
# 11                 LDA       0.924971     0.001395
# 12                 QDA       0.812965     0.087090
# 13          GaussianNB       0.789332     0.114620

# %%
# !pip install optuna
import optuna
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.ensemble import (
    GradientBoostingClassifier, HistGradientBoostingClassifier,
    VotingClassifier, RandomForestClassifier
)
from xgboost import XGBClassifier

# Setup CV
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 1. GradientBoost
def objective_gb(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 300),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2),
        "max_depth": trial.suggest_int("max_depth", 3, 7),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None])
    }
    model = GradientBoostingClassifier(**params, random_state=42)
    return cross_val_score(model, X_train_res, y_train_res, cv=cv, scoring='accuracy').mean()

# 2. HistGradientBoost
def objective_hgb(trial):
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2),
        "max_iter": trial.suggest_int("max_iter", 100, 300),
        "max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 10, 50),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 10, 50),
        "l2_regularization": trial.suggest_float("l2_regularization", 0.0, 10.0)
    }
    model = HistGradientBoostingClassifier(**params, random_state=42)
    return cross_val_score(model, X_train_res, y_train_res, cv=cv, scoring='accuracy').mean()

# 3. VotingClassifier
def objective_voting(trial):
    voting_type = trial.suggest_categorical("voting", ["soft", "hard"])
    model = VotingClassifier(estimators=[
        ('xgb', XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)),
        ('gb', GradientBoostingClassifier(random_state=42)),
        ('rf', RandomForestClassifier(random_state=42))
    ], voting=voting_type)
    return cross_val_score(model, X_train_res, y_train_res, cv=cv, scoring='accuracy').mean()

# Run tuning
study_gb = optuna.create_study(direction="maximize")
study_gb.optimize(objective_gb, n_trials=30)

study_hgb = optuna.create_study(direction="maximize")
study_hgb.optimize(objective_hgb, n_trials=30)

study_vote = optuna.create_study(direction="maximize")
study_vote.optimize(objective_voting, n_trials=10)

# Print best results
print("\n=== Best GradientBoost Parameters ===")
print(study_gb.best_params)
print("Best Accuracy:", study_gb.best_value)

print("\n=== Best HistGradientBoost Parameters ===")
print(study_hgb.best_params)
print("Best Accuracy:", study_hgb.best_value)

print("\n=== Best Voting Parameters ===")
print(study_vote.best_params)
print("Best Accuracy:", study_vote.best_value)
# Out:
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 13.4 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 18.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.2 colorlog-6.9.0 optuna-4.4.0
# [I 2025-06-25 16:39:09,846] A new study created in memory with name: no-name-ac13503e-6a36-4b4a-893e-cc07038d92d5
# [I 2025-06-25 16:58:30,864] Trial 0 finished with value: 0.9428836478131783 and parameters: {'n_estimators': 243, 'learning_rate': 0.012590379738177684, 'max_depth': 7, 'subsample': 0.740101275629998, 'max_features': None}. Best is trial 0 with value: 0.9428836478131783.
# [I 2025-06-25 17:13:11,036] Trial 1 finished with value: 0.9744156811577984 and parameters: {'n_estimators': 193, 'learning_rate': 0.06413004467094115, 'max_depth': 7, 'subsample': 0.6874133603421295, 'max_features': None}. Best is trial 1 with value: 0.9744156811577984.
# [I 2025-06-25 17:21:06,877] Trial 2 finished with value: 0.9582959860471423 and parameters: {'n_estimators': 213, 'learning_rate': 0.13409449189867367, 'max_depth': 3, 'subsample': 0.7788684584211095, 'max_features': None}. Best is trial 1 with value: 0.9744156811577984.
# [I 2025-06-25 17:28:50,630] Trial 3 finished with value: 0.9475462095353047 and parameters: {'n_estimators': 279, 'learning_rate': 0.023841243139606276, 'max_depth': 6, 'subsample': 0.8862868973208546, 'max_features': 'log2'}. Best is trial 1 with value: 0.9744156811577984.
# [I 2025-06-25 17:35:07,901] Trial 4 finished with value: 0.9771454773006129 and parameters: {'n_estimators': 215, 'learning_rate': 0.1424520432039906, 'max_depth': 7, 'subsample': 0.6624769818177323, 'max_features': 'log2'}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 17:37:31,613] Trial 5 finished with value: 0.9306992223418433 and parameters: {'n_estimators': 167, 'learning_rate': 0.0780073895331334, 'max_depth': 3, 'subsample': 0.9482006294447876, 'max_features': 'log2'}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 17:51:59,137] Trial 6 finished with value: 0.9653595633888112 and parameters: {'n_estimators': 242, 'learning_rate': 0.10740820229043524, 'max_depth': 4, 'subsample': 0.9902130037359853, 'max_features': None}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 18:00:19,249] Trial 7 finished with value: 0.9570904956765819 and parameters: {'n_estimators': 223, 'learning_rate': 0.11570807677413754, 'max_depth': 3, 'subsample': 0.7844943819452225, 'max_features': None}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 18:05:41,462] Trial 8 finished with value: 0.9485225606724608 and parameters: {'n_estimators': 239, 'learning_rate': 0.042577264235569276, 'max_depth': 5, 'subsample': 0.9083476524813304, 'max_features': 'log2'}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 18:20:28,287] Trial 9 finished with value: 0.9709486546105686 and parameters: {'n_estimators': 270, 'learning_rate': 0.1606229708305851, 'max_depth': 4, 'subsample': 0.9057680774026171, 'max_features': None}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 18:22:52,151] Trial 10 finished with value: 0.9702911243343589 and parameters: {'n_estimators': 110, 'learning_rate': 0.18696080776520324, 'max_depth': 6, 'subsample': 0.6104921970370354, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 18:28:03,476] Trial 11 finished with value: 0.970121754489708 and parameters: {'n_estimators': 178, 'learning_rate': 0.07357590650323907, 'max_depth': 7, 'subsample': 0.6493442633566116, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 18:32:54,184] Trial 12 finished with value: 0.9659174851306703 and parameters: {'n_estimators': 161, 'learning_rate': 0.06586884855539231, 'max_depth': 7, 'subsample': 0.68429822814224, 'max_features': 'log2'}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 18:36:04,777] Trial 13 finished with value: 0.9694642108135143 and parameters: {'n_estimators': 132, 'learning_rate': 0.1395759643214268, 'max_depth': 6, 'subsample': 0.7108423583874064, 'max_features': 'log2'}. Best is trial 4 with value: 0.9771454773006129.
# [I 2025-06-25 18:41:27,133] Trial 14 finished with value: 0.9772849631953304 and parameters: {'n_estimators': 193, 'learning_rate': 0.19048750287414568, 'max_depth': 7, 'subsample': 0.6046726042398473, 'max_features': 'sqrt'}. Best is trial 14 with value: 0.9772849631953304.
# [I 2025-06-25 18:44:46,920] Trial 15 finished with value: 0.9737681140179841 and parameters: {'n_estimators': 151, 'learning_rate': 0.19566040666910553, 'max_depth': 6, 'subsample': 0.6103803210017631, 'max_features': 'sqrt'}. Best is trial 14 with value: 0.9772849631953304.
# [I 2025-06-25 18:49:00,737] Trial 16 finished with value: 0.9709187666902697 and parameters: {'n_estimators': 195, 'learning_rate': 0.16846060941648, 'max_depth': 5, 'subsample': 0.8500007462488289, 'max_features': 'sqrt'}. Best is trial 14 with value: 0.9772849631953304.
# [I 2025-06-25 18:54:26,324] Trial 17 finished with value: 0.9739773240008234 and parameters: {'n_estimators': 293, 'learning_rate': 0.16440185729551499, 'max_depth': 5, 'subsample': 0.6517168605826006, 'max_features': 'sqrt'}. Best is trial 14 with value: 0.9772849631953304.
# [I 2025-06-25 19:00:57,445] Trial 18 finished with value: 0.9772451061830877 and parameters: {'n_estimators': 210, 'learning_rate': 0.1359652652444407, 'max_depth': 7, 'subsample': 0.7383179355569368, 'max_features': 'log2'}. Best is trial 14 with value: 0.9772849631953304.
# [I 2025-06-25 19:04:26,205] Trial 19 finished with value: 0.9735290066852272 and parameters: {'n_estimators': 132, 'learning_rate': 0.19982802372537406, 'max_depth': 6, 'subsample': 0.8285196672745817, 'max_features': 'sqrt'}. Best is trial 14 with value: 0.9772849631953304.
# [I 2025-06-25 19:10:08,045] Trial 20 finished with value: 0.9740271461346444 and parameters: {'n_estimators': 184, 'learning_rate': 0.09407437454659656, 'max_depth': 7, 'subsample': 0.7386209335030101, 'max_features': 'log2'}. Best is trial 14 with value: 0.9772849631953304.
# [I 2025-06-25 19:16:19,854] Trial 21 finished with value: 0.976906378901179 and parameters: {'n_estimators': 214, 'learning_rate': 0.14009683697558417, 'max_depth': 7, 'subsample': 0.643245790516505, 'max_features': 'log2'}. Best is trial 14 with value: 0.9772849631953304.
# [I 2025-06-25 19:23:20,563] Trial 22 finished with value: 0.9773048850014596 and parameters: {'n_estimators': 226, 'learning_rate': 0.12697175921568388, 'max_depth': 7, 'subsample': 0.7360481605176139, 'max_features': 'log2'}. Best is trial 22 with value: 0.9773048850014596.
# [I 2025-06-25 19:29:40,495] Trial 23 finished with value: 0.9767469726892193 and parameters: {'n_estimators': 256, 'learning_rate': 0.18326911050691666, 'max_depth': 6, 'subsample': 0.743439603044303, 'max_features': 'log2'}. Best is trial 22 with value: 0.9773048850014596.
# [I 2025-06-25 19:36:23,986] Trial 24 finished with value: 0.9764182010992701 and parameters: {'n_estimators': 202, 'learning_rate': 0.12120956657997865, 'max_depth': 7, 'subsample': 0.8236986757147985, 'max_features': 'log2'}. Best is trial 22 with value: 0.9773048850014596.
# [I 2025-06-25 19:42:15,263] Trial 25 finished with value: 0.9756211769876117 and parameters: {'n_estimators': 232, 'learning_rate': 0.15288752681573656, 'max_depth': 6, 'subsample': 0.7693996275790503, 'max_features': 'sqrt'}. Best is trial 22 with value: 0.9773048850014596.
# [I 2025-06-25 19:47:38,474] Trial 26 finished with value: 0.9729113155546149 and parameters: {'n_estimators': 178, 'learning_rate': 0.0874922256080577, 'max_depth': 7, 'subsample': 0.690243019767511, 'max_features': 'log2'}. Best is trial 22 with value: 0.9773048850014596.
# [I 2025-06-25 19:51:36,365] Trial 27 finished with value: 0.9671727762943361 and parameters: {'n_estimators': 255, 'learning_rate': 0.1767504076964783, 'max_depth': 4, 'subsample': 0.7137758780113732, 'max_features': 'sqrt'}. Best is trial 22 with value: 0.9773048850014596.
# [I 2025-06-25 19:56:56,364] Trial 28 finished with value: 0.9733795680763244 and parameters: {'n_estimators': 203, 'learning_rate': 0.12419219282892781, 'max_depth': 6, 'subsample': 0.8154707963851852, 'max_features': 'log2'}. Best is trial 22 with value: 0.9773048850014596.
# [I 2025-06-25 20:04:37,716] Trial 29 finished with value: 0.9763086095766956 and parameters: {'n_estimators': 227, 'learning_rate': 0.10186904128463778, 'max_depth': 7, 'subsample': 0.8569736975474304, 'max_features': 'sqrt'}. Best is trial 22 with value: 0.9773048850014596.
# [I 2025-06-25 20:04:37,719] A new study created in memory with name: no-name-d5c72413-0342-4c0f-a4d8-fc7ced9a6f35
# [I 2025-06-25 20:05:33,281] Trial 0 finished with value: 0.9722338520574745 and parameters: {'learning_rate': 0.10314474824994684, 'max_iter': 204, 'max_leaf_nodes': 16, 'min_samples_leaf': 27, 'l2_regularization': 2.269961045644957}. Best is trial 0 with value: 0.9722338520574745.
# [I 2025-06-25 20:07:15,829] Trial 1 finished with value: 0.9779823549504443 and parameters: {'learning_rate': 0.09258021400073321, 'max_iter': 299, 'max_leaf_nodes': 40, 'min_samples_leaf': 14, 'l2_regularization': 2.858083035314807}. Best is trial 1 with value: 0.9779823549504443.
# [I 2025-06-25 20:08:44,357] Trial 2 finished with value: 0.9646920689836149 and parameters: {'learning_rate': 0.01568545587764477, 'max_iter': 250, 'max_leaf_nodes': 33, 'min_samples_leaf': 36, 'l2_regularization': 0.3763440777676452}. Best is trial 1 with value: 0.9779823549504443.
# [I 2025-06-25 20:09:25,015] Trial 3 finished with value: 0.9758901836554685 and parameters: {'learning_rate': 0.1976167738463772, 'max_iter': 122, 'max_leaf_nodes': 32, 'min_samples_leaf': 16, 'l2_regularization': 5.394858384370783}. Best is trial 1 with value: 0.9779823549504443.
# [I 2025-06-25 20:10:04,584] Trial 4 finished with value: 0.976408239451762 and parameters: {'learning_rate': 0.17629916441363547, 'max_iter': 137, 'max_leaf_nodes': 23, 'min_samples_leaf': 31, 'l2_regularization': 0.3604798170705037}. Best is trial 1 with value: 0.9779823549504443.
# [I 2025-06-25 20:11:25,451] Trial 5 finished with value: 0.9780819882995806 and parameters: {'learning_rate': 0.14136331768380903, 'max_iter': 239, 'max_leaf_nodes': 47, 'min_samples_leaf': 50, 'l2_regularization': 2.228360259344049}. Best is trial 5 with value: 0.9780819882995806.
# [I 2025-06-25 20:12:30,646] Trial 6 finished with value: 0.9745452118568518 and parameters: {'learning_rate': 0.10202995665198204, 'max_iter': 184, 'max_leaf_nodes': 35, 'min_samples_leaf': 39, 'l2_regularization': 7.524751039154633}. Best is trial 5 with value: 0.9780819882995806.
# [I 2025-06-25 20:13:25,212] Trial 7 finished with value: 0.9692251019918704 and parameters: {'learning_rate': 0.03495719708305515, 'max_iter': 136, 'max_leaf_nodes': 49, 'min_samples_leaf': 41, 'l2_regularization': 3.309224770440543}. Best is trial 5 with value: 0.9780819882995806.
# [I 2025-06-25 20:14:09,426] Trial 8 finished with value: 0.9701117878792427 and parameters: {'learning_rate': 0.07013638193357667, 'max_iter': 115, 'max_leaf_nodes': 37, 'min_samples_leaf': 47, 'l2_regularization': 8.42361998988279}. Best is trial 5 with value: 0.9780819882995806.
# [I 2025-06-25 20:15:26,726] Trial 9 finished with value: 0.9556957181219028 and parameters: {'learning_rate': 0.016628654597689536, 'max_iter': 255, 'max_leaf_nodes': 16, 'min_samples_leaf': 20, 'l2_regularization': 5.268793627311671}. Best is trial 5 with value: 0.9780819882995806.
# [I 2025-06-25 20:16:46,697] Trial 10 finished with value: 0.9775340301904126 and parameters: {'learning_rate': 0.14869022779022933, 'max_iter': 205, 'max_leaf_nodes': 50, 'min_samples_leaf': 50, 'l2_regularization': 6.8079779364700235}. Best is trial 5 with value: 0.9780819882995806.
# [I 2025-06-25 20:18:23,064] Trial 11 finished with value: 0.9787395220498603 and parameters: {'learning_rate': 0.13969143763289438, 'max_iter': 299, 'max_leaf_nodes': 43, 'min_samples_leaf': 11, 'l2_regularization': 2.681573604971808}. Best is trial 11 with value: 0.9787395220498603.
# [I 2025-06-25 20:19:54,954] Trial 12 finished with value: 0.9790483678633141 and parameters: {'learning_rate': 0.1418250785567518, 'max_iter': 299, 'max_leaf_nodes': 41, 'min_samples_leaf': 10, 'l2_regularization': 2.00055589891088}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:21:37,048] Trial 13 finished with value: 0.978261308376938 and parameters: {'learning_rate': 0.13777317054651123, 'max_iter': 299, 'max_leaf_nodes': 42, 'min_samples_leaf': 11, 'l2_regularization': 3.8425025483564594}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:22:56,209] Trial 14 finished with value: 0.9781517238025035 and parameters: {'learning_rate': 0.1558331754316718, 'max_iter': 277, 'max_leaf_nodes': 26, 'min_samples_leaf': 21, 'l2_regularization': 1.2451446041777192}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:24:37,294] Trial 15 finished with value: 0.9772052600893506 and parameters: {'learning_rate': 0.12613051333266145, 'max_iter': 272, 'max_leaf_nodes': 43, 'min_samples_leaf': 11, 'l2_regularization': 9.903755256496275}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:25:55,045] Trial 16 finished with value: 0.9782114877320044 and parameters: {'learning_rate': 0.1805832284381605, 'max_iter': 227, 'max_leaf_nodes': 44, 'min_samples_leaf': 23, 'l2_regularization': 4.123624010003871}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:26:52,329] Trial 17 finished with value: 0.9750134614007872 and parameters: {'learning_rate': 0.07803043585165334, 'max_iter': 162, 'max_leaf_nodes': 38, 'min_samples_leaf': 16, 'l2_regularization': 1.5507510220873684}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:28:19,352] Trial 18 finished with value: 0.97691634253387 and parameters: {'learning_rate': 0.11922412352724121, 'max_iter': 279, 'max_leaf_nodes': 29, 'min_samples_leaf': 10, 'l2_regularization': 4.955192914419164}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:29:26,611] Trial 19 finished with value: 0.9786199693760732 and parameters: {'learning_rate': 0.16385833353686036, 'max_iter': 220, 'max_leaf_nodes': 45, 'min_samples_leaf': 27, 'l2_regularization': 1.3035588138038527}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:30:43,750] Trial 20 finished with value: 0.9760196974804678 and parameters: {'learning_rate': 0.12095221055137959, 'max_iter': 261, 'max_leaf_nodes': 23, 'min_samples_leaf': 19, 'l2_regularization': 4.096758970885363}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:32:00,035] Trial 21 finished with value: 0.9788491150613217 and parameters: {'learning_rate': 0.16534046575427702, 'max_iter': 289, 'max_leaf_nodes': 46, 'min_samples_leaf': 26, 'l2_regularization': 1.5610079934470544}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:32:51,138] Trial 22 finished with value: 0.9782712739948121 and parameters: {'learning_rate': 0.17089003233462235, 'max_iter': 287, 'max_leaf_nodes': 40, 'min_samples_leaf': 31, 'l2_regularization': 0.048199047061805445}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:33:58,080] Trial 23 finished with value: 0.9786996729783486 and parameters: {'learning_rate': 0.19491366688435177, 'max_iter': 295, 'max_leaf_nodes': 46, 'min_samples_leaf': 14, 'l2_regularization': 2.2952812305948025}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:35:00,968] Trial 24 finished with value: 0.9724530341100321 and parameters: {'learning_rate': 0.13458544311277051, 'max_iter': 266, 'max_leaf_nodes': 10, 'min_samples_leaf': 26, 'l2_regularization': 1.1098526206067794}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:36:26,503] Trial 25 finished with value: 0.978888964132833 and parameters: {'learning_rate': 0.15859416141263277, 'max_iter': 243, 'max_leaf_nodes': 50, 'min_samples_leaf': 17, 'l2_regularization': 3.0508045099577576}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:37:51,846] Trial 26 finished with value: 0.9785900784780001 and parameters: {'learning_rate': 0.1571710472555118, 'max_iter': 242, 'max_leaf_nodes': 50, 'min_samples_leaf': 24, 'l2_regularization': 3.4646947933953633}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:39:12,104] Trial 27 finished with value: 0.9785203424787813 and parameters: {'learning_rate': 0.18416779862491772, 'max_iter': 228, 'max_leaf_nodes': 47, 'min_samples_leaf': 19, 'l2_regularization': 4.7265469603675445}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:40:49,577] Trial 28 finished with value: 0.9781218334007262 and parameters: {'learning_rate': 0.16184616972403082, 'max_iter': 281, 'max_leaf_nodes': 39, 'min_samples_leaf': 16, 'l2_regularization': 6.035854700703489}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:42:04,016] Trial 29 finished with value: 0.9778528386439662 and parameters: {'learning_rate': 0.113447059272277, 'max_iter': 203, 'max_leaf_nodes': 48, 'min_samples_leaf': 29, 'l2_regularization': 2.1519052762154507}. Best is trial 12 with value: 0.9790483678633141.
# [I 2025-06-25 20:42:04,019] A new study created in memory with name: no-name-d5aff7e4-fe91-4b98-9bd5-eb4ab1eafc8c
# [I 2025-06-25 20:48:00,840] Trial 0 finished with value: 0.9738577817492462 and parameters: {'voting': 'hard'}. Best is trial 0 with value: 0.9738577817492462.
# [I 2025-06-25 20:53:56,663] Trial 1 finished with value: 0.9738577817492462 and parameters: {'voting': 'hard'}. Best is trial 0 with value: 0.9738577817492462.
# [I 2025-06-25 20:59:53,671] Trial 2 finished with value: 0.9738577817492462 and parameters: {'voting': 'hard'}. Best is trial 0 with value: 0.9738577817492462.
# [I 2025-06-25 21:05:51,648] Trial 3 finished with value: 0.9767469716966278 and parameters: {'voting': 'soft'}. Best is trial 3 with value: 0.9767469716966278.
# [I 2025-06-25 21:11:50,659] Trial 4 finished with value: 0.9738577817492462 and parameters: {'voting': 'hard'}. Best is trial 3 with value: 0.9767469716966278.
# [I 2025-06-25 21:17:46,366] Trial 5 finished with value: 0.9738577817492462 and parameters: {'voting': 'hard'}. Best is trial 3 with value: 0.9767469716966278.
# [I 2025-06-25 21:23:45,387] Trial 6 finished with value: 0.9738577817492462 and parameters: {'voting': 'hard'}. Best is trial 3 with value: 0.9767469716966278.
# [I 2025-06-25 21:29:41,035] Trial 7 finished with value: 0.9738577817492462 and parameters: {'voting': 'hard'}. Best is trial 3 with value: 0.9767469716966278.
# [I 2025-06-25 21:35:32,773] Trial 8 finished with value: 0.9738577817492462 and parameters: {'voting': 'hard'}. Best is trial 3 with value: 0.9767469716966278.
# [I 2025-06-25 21:41:26,990] Trial 9 finished with value: 0.9767469716966278 and parameters: {'voting': 'soft'}. Best is trial 3 with value: 0.9767469716966278.
# === Best GradientBoost Parameters ===
# {'n_estimators': 226, 'learning_rate': 0.12697175921568388, 'max_depth': 7, 'subsample': 0.7360481605176139, 'max_features': 'log2'}
# Best Accuracy: 0.9773048850014596
#
# === Best HistGradientBoost Parameters ===
# {'learning_rate': 0.1418250785567518, 'max_iter': 299, 'max_leaf_nodes': 41, 'min_samples_leaf': 10, 'l2_regularization': 2.00055589891088}
# Best Accuracy: 0.9790483678633141
#
# === Best Voting Parameters ===
# {'voting': 'soft'}
# Best Accuracy: 0.9767469716966278

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import GradientBoostingClassifier, HistGradientBoostingClassifier, VotingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt

# === Final GradientBoost ===
gb_best = GradientBoostingClassifier(
    n_estimators=226,
    learning_rate=0.12697175921568388,
    max_depth=7,
    subsample=0.7360481605176139,
    max_features='log2',
    random_state=42
)
gb_best.fit(X_train_res, y_train_res)
y_pred_gb = gb_best.predict(X_test)

print("=== GradientBoost ===")
print("Accuracy:", accuracy_score(y_test, y_pred_gb))
print(classification_report(y_test, y_pred_gb))

cm_gb = confusion_matrix(y_test, y_pred_gb)
ConfusionMatrixDisplay(cm_gb, display_labels=[1, 2, 3]).plot(cmap="Blues")
plt.title("Confusion Matrix - GradientBoost (Skenario 3.1)")
plt.show()

# === Final HistGradientBoost ===
hgb_best = HistGradientBoostingClassifier(
    learning_rate=0.1418250785567518,
    max_iter=299,
    max_leaf_nodes=41,
    min_samples_leaf=10,
    l2_regularization=2.00055589891088,
    random_state=42
)
hgb_best.fit(X_train_res, y_train_res)
y_pred_hgb = hgb_best.predict(X_test)

print("\n=== HistGradientBoost ===")
print("Accuracy:", accuracy_score(y_test, y_pred_hgb))
print(classification_report(y_test, y_pred_hgb))

cm_hgb = confusion_matrix(y_test, y_pred_hgb)
ConfusionMatrixDisplay(cm_hgb, display_labels=[1, 2, 3]).plot(cmap="Greens")
plt.title("Confusion Matrix - HistGradientBoost (Skenario 3.1)")
plt.show()

# === Final VotingClassifier ===
voting_best = VotingClassifier(estimators=[
    ('xgb', XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)),
    ('gb', GradientBoostingClassifier(random_state=42)),
    ('rf', RandomForestClassifier(random_state=42))
], voting='soft')

voting_best.fit(X_train_res, y_train_res)
y_pred_vote = voting_best.predict(X_test)

print("\n=== VotingClassifier ===")
print("Accuracy:", accuracy_score(y_test, y_pred_vote))
print(classification_report(y_test, y_pred_vote))

cm_vote = confusion_matrix(y_test, y_pred_vote)
ConfusionMatrixDisplay(cm_vote, display_labels=[1, 2, 3]).plot(cmap="Purples")
plt.title("Confusion Matrix - VotingClassifier (Skenario 3.1)")
plt.show()
# Out:
# === GradientBoost ===
# Accuracy: 0.9585209003215434
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80       129
#            1       0.88      0.68      0.77       836
#            2       0.97      0.99      0.98      8365
#
#     accuracy                           0.96      9330
#    macro avg       0.91      0.80      0.85      9330
# weighted avg       0.96      0.96      0.96      9330
# === HistGradientBoost ===
# Accuracy: 0.9555198285101822
#               precision    recall  f1-score   support
#
#            0       0.84      0.74      0.79       129
#            1       0.84      0.69      0.76       836
#            2       0.97      0.99      0.98      8365
#
#     accuracy                           0.96      9330
#    macro avg       0.88      0.80      0.84      9330
# weighted avg       0.95      0.96      0.95      9330
# === VotingClassifier ===
# Accuracy: 0.959914255091104
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82       129
#            1       0.89      0.68      0.77       836
#            2       0.97      0.99      0.98      8365
#
#     accuracy                           0.96      9330
#    macro avg       0.93      0.80      0.86      9330
# weighted avg       0.96      0.96      0.96      9330
