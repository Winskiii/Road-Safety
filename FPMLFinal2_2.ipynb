# %%
import pandas as pd

df = pd.read_csv('train_road_safety.csv')

df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46649 entries, 0 to 46648
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   status                              44293 non-null  object
#  1   collision_index                     46649 non-null  object
#  2   collision_year                      44261 non-null  float64
#  3   collision_reference                 44343 non-null  object
#  4   vehicle_reference                   46649 non-null  float64
#  5   casualty_reference                  46649 non-null  float64
#  6   casualty_class                      46649 non-null  int64
#  7   sex_of_casualty                     44319 non-null  float64
#  8   age_of_casualty                     46649 non-null  int64
#  9   age_band_of_casualty                46649 non-null  int64
#  10  pedestrian_location                 46649 non-null  float64
#  11  pedestrian_movement                 46649 non-null  int64
#  12  car_passenger                       46649 non-null  int64
#  13  bus_or_coach_passenger              46649 non-null  int64
#  14  pedestrian_road_maintenance_worker  44314 non-null  float64
#  15  casualty_type                       46649 non-null  int64
#  16  casualty_home_area_type             44292 non-null  float64
#  17  casualty_imd_decile                 46649 non-null  int64
#  18  lsoa_of_casualty                    46649 non-null  object
#  19  enhanced_casualty_severity          46649 non-null  int64
#  20  casualty_severity                   46649 non-null  int64
# dtypes: float64(7), int64(10), object(4)
# memory usage: 7.5+ MB
#        collision_year  vehicle_reference  casualty_reference  casualty_class  \
# count         44261.0       46649.000000        46649.000000    46649.000000
# mean           2024.0           1.455616            1.353898        1.485520
# std               0.0           1.444068            1.267332        0.732898
# min            2024.0           0.462251            0.595506        1.000000
# 25%            2024.0           1.000000            1.000000        1.000000
# 50%            2024.0           1.000000            1.000000        1.000000
# 75%            2024.0           2.000000            1.000000        2.000000
# max            2024.0         203.000000          202.000000        3.000000
#
#        sex_of_casualty  age_of_casualty  age_band_of_casualty  \
# count     44319.000000     46649.000000          46649.000000
# mean          1.366637        37.102982              6.326502
# std           0.577406        19.826586              2.493991
# min          -1.000000        -1.000000             -1.000000
# 25%           1.000000        22.000000              5.000000
# 50%           1.000000        34.000000              6.000000
# 75%           2.000000        51.000000              8.000000
# max           9.000000       120.000000             11.000000
#
#        pedestrian_location  pedestrian_movement  car_passenger  \
# count         46649.000000         46649.000000   46649.000000
# mean              0.795227             0.657442       0.196574
# std               2.196648             2.047634       0.647400
# min              -1.000000            -1.000000      -1.000000
# 25%               0.000000             0.000000       0.000000
# 50%               0.000000             0.000000       0.000000
# 75%               0.000000             0.000000       0.000000
# max              10.334651             9.000000       9.000000
#
#        bus_or_coach_passenger  pedestrian_road_maintenance_worker  \
# count            46649.000000                        44314.000000
# mean                 0.058072                            0.031548
# std                  0.465305                            0.286917
# min                 -1.000000                           -1.000000
# 25%                  0.000000                            0.000000
# 50%                  0.000000                            0.000000
# 75%                  0.000000                            0.000000
# max                  9.000000                            2.000000
#
#        casualty_type  casualty_home_area_type  casualty_imd_decile  \
# count   46649.000000             44292.000000         46649.000000
# mean        9.314112                 0.993227             4.132307
# std        15.842578                 0.979042             3.286280
# min        -1.000000                -1.000000            -1.000000
# 25%         2.000000                 1.000000             2.000000
# 50%         9.000000                 1.000000             4.000000
# 75%         9.000000                 1.000000             7.000000
# max        98.000000                 3.000000            10.000000
#
#        enhanced_casualty_severity  casualty_severity
# count                46649.000000       46649.000000
# mean                     1.582220           2.882741
# std                      2.273239           0.362108
# min                     -1.000000           1.000000
# 25%                     -1.000000           3.000000
# 50%                      3.000000           3.000000
# 75%                      3.000000           3.000000
# max                      7.000000           3.000000

# %%
import numpy as np

df.drop(columns=["status", "collision_year", "collision_reference","lsoa_of_casualty","age_band_of_casualty","collision_index",], inplace=True)

#imputasi dengan modus
sex_mode = df["sex_of_casualty"].mode()[0]
df["sex_of_casualty"].fillna(sex_mode, inplace=True)

#imputasi dengan modus
worker_mode = df["pedestrian_road_maintenance_worker"].mode()[0]
df["pedestrian_road_maintenance_worker"].fillna(worker_mode, inplace=True)

#imputasi dengan modus
area_type_mode = df["casualty_home_area_type"].mode()[0]
df["casualty_home_area_type"].fillna(area_type_mode, inplace=True)

# Identifikasi nilai absurd
mask_invalid = df['pedestrian_location'] > 100

# Ganti nilai absurd dengan 0 atau NaN jika tidak bisa dipercaya
df.loc[mask_invalid, 'pedestrian_location'] = 0

# Set pedestrian_location = 0 bila pedestrian_movement == 0
df.loc[df['pedestrian_movement'] == 0, 'pedestrian_location'] = 0

# Gabungkan sebagai string lalu encode dan drop kolom aslinya
df['pedestrian_context'] = df['pedestrian_location'].astype(str) + "_" + df['pedestrian_movement'].astype(str)
df.drop(columns=['pedestrian_location', 'pedestrian_movement'], inplace=True)

# Ganti nilai tidak valid dengan NaN
df['casualty_home_area_type'].replace([-10, 10, 20, 30], np.nan, inplace=True)
df['casualty_imd_decile'].replace(-1, np.nan, inplace=True)

# Imputasi NaN dengan modus
home_mode = df['casualty_home_area_type'].mode()[0]
imd_mode = df['casualty_imd_decile'].mode()[0]

df['casualty_home_area_type'].fillna(home_mode, inplace=True)
df['casualty_imd_decile'].fillna(imd_mode, inplace=True)


missing = df.isnull().sum()
print(missing[missing > 0])

df.isnull().sum()
# Out:
# Series([], dtype: int64)
# /tmp/ipython-input-2-3428061107.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["sex_of_casualty"].fillna(sex_mode, inplace=True)
# /tmp/ipython-input-2-3428061107.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["pedestrian_road_maintenance_worker"].fillna(worker_mode, inplace=True)
# /tmp/ipython-input-2-3428061107.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["casualty_home_area_type"].fillna(area_type_mode, inplace=True)
# /tmp/ipython-input-2-3428061107.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['casualty_home_area_type'].replace([-10, 10, 20, 30], np.nan, inplace=True)
# /tmp/ipython-input-2-3428061107.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['casualty_imd_decile'].replace(-1, np.nan, inplace=True)
# /tmp/ipython-input-2-3428061107.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['casualty_home_area_type'].fillna(home_mode, inplace=True)
# vehicle_reference                     0
# casualty_reference                    0
# casualty_class                        0
# sex_of_casualty                       0
# age_of_casualty                       0
# car_passenger                         0
# bus_or_coach_passenger                0
# pedestrian_road_maintenance_worker    0
# casualty_type                         0
# casualty_home_area_type               0
# casualty_imd_decile                   0
# enhanced_casualty_severity            0
# casualty_severity                     0
# pedestrian_context                    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder

X = df.drop(columns=["casualty_severity"])
y = df["casualty_severity"] - 1  # klasifikasi 0, 1, 2

label_encoders = {}
for col in X.select_dtypes(include="object").columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))
    label_encoders[col] = le

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

from sklearn.ensemble import (
    RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier,
    BaggingClassifier, VotingClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier
)
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from xgboost import XGBClassifier

models = [
    ("LogisticRegression", LogisticRegression(max_iter=1000, random_state=42)),
    ("KNN", KNeighborsClassifier(n_neighbors=5)),
    ("GaussianNB", GaussianNB()),
    ("Decision Tree", DecisionTreeClassifier(random_state=42)),
    ("Random Forest", RandomForestClassifier(random_state=42)),
    ("ExtraTrees", ExtraTreesClassifier(random_state=42)),
    ("Bagging", BaggingClassifier(random_state=42)),
    ("AdaBoost", AdaBoostClassifier(random_state=42)),
    ("GradientBoost", GradientBoostingClassifier(random_state=42)),
    ("HistGradientBoost", HistGradientBoostingClassifier(random_state=42)),
    ("XGBoost", XGBClassifier(use_label_encoder=False, eval_metric="mlogloss", random_state=42)),
    ("LDA", LinearDiscriminantAnalysis()),
    ("QDA", QuadraticDiscriminantAnalysis())
]

# Tambahkan Voting Classifier
voting = VotingClassifier(estimators=[
    ("xgb", XGBClassifier(use_label_encoder=False, eval_metric="mlogloss", random_state=42)),
    ("gb", GradientBoostingClassifier(random_state=42)),
    ("rf", RandomForestClassifier(random_state=42))
], voting="soft")
models.append(("Voting", voting))

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
results = []

for name, model in models:
    try:
        scores = cross_val_score(model, X_train, y_train, scoring="accuracy", cv=cv, n_jobs=-1)
        results.append((name, scores.mean(), scores.std()))
    except Exception as e:
        print(f"{name} error: {e}")

results_df = pd.DataFrame(results, columns=["Algorithm", "CrossValMeans", "CrossValStd"])
results_df = results_df.sort_values(by="CrossValMeans", ascending=False).reset_index(drop=True)

print("Fitur yang digunakan:")
print(X.columns.tolist())
print(results_df)
# Out:
# Fitur yang digunakan:
# ['vehicle_reference', 'casualty_reference', 'casualty_class', 'sex_of_casualty', 'age_of_casualty', 'car_passenger', 'bus_or_coach_passenger', 'pedestrian_road_maintenance_worker', 'casualty_type', 'casualty_home_area_type', 'casualty_imd_decile', 'enhanced_casualty_severity', 'pedestrian_context']
#              Algorithm  CrossValMeans  CrossValStd
# 0        GradientBoost       0.966693     0.000865
# 1               Voting       0.966532     0.000739
# 2    HistGradientBoost       0.966505     0.001107
# 3              XGBoost       0.965755     0.001049
# 4        Random Forest       0.960342     0.001219
# 5             AdaBoost       0.956376     0.000952
# 6              Bagging       0.954018     0.001248
# 7           ExtraTrees       0.953429     0.001458
# 8                  KNN       0.937753     0.001399
# 9        Decision Tree       0.934725     0.002031
# 10  LogisticRegression       0.927758     0.001129
# 11                 LDA       0.924971     0.001395
# 12                 QDA       0.812965     0.087090
# 13          GaussianNB       0.789332     0.114620

# %%
# !pip install optuna --quiet

import optuna
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier, HistGradientBoostingClassifier, VotingClassifier, RandomForestClassifier
from xgboost import XGBClassifier

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# === GradientBoost ===
def objective_gb(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    }
    model = GradientBoostingClassifier(**params, random_state=42)
    return cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy').mean()

study_gb = optuna.create_study(direction='maximize')
study_gb.optimize(objective_gb, n_trials=30)

# === HistGradientBoost ===
def objective_hgb(trial):
    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_iter': trial.suggest_int('max_iter', 100, 300),
        'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 10, 50),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 10, 50),
        'l2_regularization': trial.suggest_float('l2_regularization', 0.0, 10.0)
    }
    model = HistGradientBoostingClassifier(**params, random_state=42)
    return cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy').mean()

study_hgb = optuna.create_study(direction='maximize')
study_hgb.optimize(objective_hgb, n_trials=30)

# === VotingClassifier (soft) ===
def objective_vote(trial):
    voting_type = trial.suggest_categorical("voting", ["soft", "hard"])
    model = VotingClassifier(estimators=[
        ('xgb', XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)),
        ('gb', GradientBoostingClassifier(random_state=42)),
        ('rf', RandomForestClassifier(random_state=42))
    ], voting=voting_type)
    return cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy').mean()

study_vote = optuna.create_study(direction='maximize')
study_vote.optimize(objective_vote, n_trials=10)

# === Print Best Results ===
print("=== Best GradientBoost Parameters ===")
print(study_gb.best_params)
print("Best Accuracy:", study_gb.best_value)

print("\n=== Best HistGradientBoost Parameters ===")
print(study_hgb.best_params)
print("Best Accuracy:", study_hgb.best_value)

print("\n=== Best Voting Parameters ===")
print(study_vote.best_params)
print("Best Accuracy:", study_vote.best_value)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 9.7 MB/s eta 0:00:00
# [I 2025-06-25 14:51:06,996] A new study created in memory with name: no-name-b807759f-bd05-4ee9-9827-d14ff217714b
# [I 2025-06-25 14:51:44,064] Trial 0 finished with value: 0.9663978521262238 and parameters: {'n_estimators': 197, 'learning_rate': 0.18163128124687772, 'max_depth': 3, 'subsample': 0.7832287772301545, 'max_features': 'log2'}. Best is trial 0 with value: 0.9663978521262238.
# [I 2025-06-25 14:52:09,172] Trial 1 finished with value: 0.9580374937221554 and parameters: {'n_estimators': 102, 'learning_rate': 0.01837312649395493, 'max_depth': 4, 'subsample': 0.7626831645848478, 'max_features': 'log2'}. Best is trial 0 with value: 0.9663978521262238.
# [I 2025-06-25 14:56:47,944] Trial 2 finished with value: 0.9652992167576551 and parameters: {'n_estimators': 196, 'learning_rate': 0.02305933932896916, 'max_depth': 10, 'subsample': 0.7303459588450125, 'max_features': None}. Best is trial 0 with value: 0.9663978521262238.
# [I 2025-06-25 15:03:30,749] Trial 3 finished with value: 0.96345029548416 and parameters: {'n_estimators': 264, 'learning_rate': 0.06061730224137999, 'max_depth': 10, 'subsample': 0.6126361559895682, 'max_features': 'log2'}. Best is trial 0 with value: 0.9663978521262238.
# [I 2025-06-25 15:04:51,400] Trial 4 finished with value: 0.9667193991250009 and parameters: {'n_estimators': 184, 'learning_rate': 0.02544841626496005, 'max_depth': 6, 'subsample': 0.9388171837131152, 'max_features': 'sqrt'}. Best is trial 4 with value: 0
# [I 2025-06-25 15:38:56,503] Trial 29 finished with value: 0.9659155190615971 and parameters: {'n_estimators': 208, 'learning_rate': 0.15072895103510697, 'max_depth': 3, 'subsample': 0.7800934428893321, 'max_features': None}. Best is trial 23 with value: 0.9667729932834781.
# [I 2025-06-25 15:38:56,505] A new study created in memory with name: no-name-a65dbcb5-aafb-45c4-89ec-d59ac6e8e552
# [I 2025-06-25 15:39:06,010] Trial 0 finished with value: 0.9669337721684927 and parameters: {'learning_rate': 0.06716945739341983, 'max_iter': 272, 'max_leaf_nodes': 35, 'min_samples_leaf': 40, 'l2_regularization': 9.073967972886445}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:14,752] Trial 1 finished with value: 0.9666658049665238 and parameters: {'learning_rate': 0.06999838962360018, 'max_iter': 283, 'max_leaf_nodes': 40, 'min_samples_leaf': 11, 'l2_regularization': 8.56079947245205}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:17,197] Trial 2 finished with value: 0.9668801780100156 and parameters: {'learning_rate': 0.23156635936604555, 'max_iter': 117, 'max_leaf_nodes': 11, 'min_samples_leaf': 50, 'l2_regularization': 1.9634835427319486}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:20,718] Trial 3 finished with value: 0.9668533791355681 and parameters: {'learning_rate': 0.22029341657721668, 'max_iter': 213, 'max_leaf_nodes': 23, 'min_samples_leaf': 30, 'l2_regularization': 7.4715889887573}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:25,731] Trial 4 finished with value: 0.9666390132729109 and parameters: {'learning_rate': 0.17814830596625197, 'max_iter': 134, 'max_leaf_nodes': 36, 'min_samples_leaf': 38, 'l2_regularization': 7.849430747177518}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:28,024] Trial 5 finished with value: 0.9667729932834781 and parameters: {'learning_rate': 0.29801605530585124, 'max_iter': 277, 'max_leaf_nodes': 11, 'min_samples_leaf': 26, 'l2_regularization': 4.000276449316072}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:30,378] Trial 6 finished with value: 0.9659155262424315 and parameters: {'learning_rate': 0.2956960035325407, 'max_iter': 284, 'max_leaf_nodes': 24, 'min_samples_leaf': 31, 'l2_regularization': 0.08271159101291059}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:36,175] Trial 7 finished with value: 0.9666390096824937 and parameters: {'learning_rate': 0.11578177891698893, 'max_iter': 144, 'max_leaf_nodes': 27, 'min_samples_leaf': 19, 'l2_regularization': 4.601473172402919}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:39,302] Trial 8 finished with value: 0.9666122215792982 and parameters: {'learning_rate': 0.28162492051001814, 'max_iter': 267, 'max_leaf_nodes': 43, 'min_samples_leaf': 33, 'l2_regularization': 2.428125178460948}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:42,325] Trial 9 finished with value: 0.9667194098962527 and parameters: {'learning_rate': 0.2853716792477195, 'max_iter': 279, 'max_leaf_nodes': 40, 'min_samples_leaf': 36, 'l2_regularization': 5.28816781093488}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:39:59,139] Trial 10 finished with value: 0.9669069697036283 and parameters: {'learning_rate': 0.030136878807345037, 'max_iter': 214, 'max_leaf_nodes': 33, 'min_samples_leaf': 46, 'l2_regularization': 9.38912090384486}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:40:19,576] Trial 11 finished with value: 0.9667997921579256 and parameters: {'learning_rate': 0.030486811120787577, 'max_iter': 221, 'max_leaf_nodes': 49, 'min_samples_leaf': 47, 'l2_regularization': 9.88347916000525}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:40:35,905] Trial 12 finished with value: 0.9668801744195983 and parameters: {'learning_rate': 0.03409930046602351, 'max_iter': 177, 'max_leaf_nodes': 32, 'min_samples_leaf': 43, 'l2_regularization': 9.791667942157702}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:40:42,825] Trial 13 finished with value: 0.9667997885675081 and parameters: {'learning_rate': 0.09730487450088418, 'max_iter': 239, 'max_leaf_nodes': 32, 'min_samples_leaf': 42, 'l2_regularization': 6.502925930971809}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:41:03,806] Trial 14 finished with value: 0.9667729968738955 and parameters: {'learning_rate': 0.01702395621099545, 'max_iter': 181, 'max_leaf_nodes': 19, 'min_samples_leaf': 43, 'l2_regularization': 8.778091000367994}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:41:11,951] Trial 15 finished with value: 0.9668265874419555 and parameters: {'learning_rate': 0.07973830992015482, 'max_iter': 240, 'max_leaf_nodes': 46, 'min_samples_leaf': 50, 'l2_regularization': 6.405834519456789}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:41:17,579] Trial 16 finished with value: 0.9668801780100156 and parameters: {'learning_rate': 0.14170968976533, 'max_iter': 250, 'max_leaf_nodes': 36, 'min_samples_leaf': 39, 'l2_regularization': 6.57221847589533}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:41:27,512] Trial 17 finished with value: 0.9668265802611209 and parameters: {'learning_rate': 0.05697485587096256, 'max_iter': 189, 'max_leaf_nodes': 29, 'min_samples_leaf': 26, 'l2_regularization': 8.495610121258485}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:41:32,979] Trial 18 finished with value: 0.9668533863164027 and parameters: {'learning_rate': 0.12600264477232198, 'max_iter': 159, 'max_leaf_nodes': 17, 'min_samples_leaf': 46, 'l2_regularization': 9.405396557195187}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:41:37,306] Trial 19 finished with value: 0.9666926074313882 and parameters: {'learning_rate': 0.17146561278440955, 'max_iter': 210, 'max_leaf_nodes': 36, 'min_samples_leaf': 35, 'l2_regularization': 7.490910783155785}. Best is trial 0 with value: 0.9669337721684927.
# [I 2025-06-25 15:41:47,884] Trial 20 finished with value: 0.966933772168493 and parameters: {'learning_rate': 0.050894784802602275, 'max_iter': 298, 'max_leaf_nodes': 33, 'min_samples_leaf': 41, 'l2_regularization': 5.69988232689694}. Best is trial 20 with value: 0.966933772168493.
# [I 2025-06-25 15:41:57,798] Trial 21 finished with value: 0.9669069732940455 and parameters: {'learning_rate': 0.05204287144015399, 'max_iter': 299, 'max_leaf_nodes': 32, 'min_samples_leaf': 41, 'l2_regularization': 5.507372648940732}. Best is trial 20 with value: 0.966933772168493.
# [I 2025-06-25 15:42:06,245] Trial 22 finished with value: 0.9669605710429401 and parameters: {'learning_rate': 0.05726669460871793, 'max_iter': 297, 'max_leaf_nodes': 27, 'min_samples_leaf': 40, 'l2_regularization': 3.4870907436642504}. Best is trial 22 with value: 0.9669605710429401.
# [I 2025-06-25 15:42:13,006] Trial 23 finished with value: 0.9668533827259855 and parameters: {'learning_rate': 0.08893319881800978, 'max_iter': 297, 'max_leaf_nodes': 26, 'min_samples_leaf': 38, 'l2_regularization': 3.3112358167329354}. Best is trial 22 with value: 0.9669605710429401.
# [I 2025-06-25 15:42:43,051] Trial 24 finished with value: 0.966799784977091 and parameters: {'learning_rate': 0.011395595598316502, 'max_iter': 258, 'max_leaf_nodes': 20, 'min_samples_leaf': 34, 'l2_regularization': 1.1798372471406537}. Best is trial 22 with value: 0.9669605710429401.
# [I 2025-06-25 15:42:48,578] Trial 25 finished with value: 0.9668265874419555 and parameters: {'learning_rate': 0.10418416944371928, 'max_iter': 300, 'max_leaf_nodes': 28, 'min_samples_leaf': 27, 'l2_regularization': 3.396048497669639}. Best is trial 22 with value: 0.9669605710429401.
# [I 2025-06-25 15:42:58,250] Trial 26 finished with value: 0.9666122143984637 and parameters: {'learning_rate': 0.050977559564592156, 'max_iter': 265, 'max_leaf_nodes': 39, 'min_samples_leaf': 20, 'l2_regularization': 4.090249100837066}. Best is trial 22 with value: 0.9669605710429401.
# [I 2025-06-25 15:43:06,006] Trial 27 finished with value: 0.9668265874419555 and parameters: {'learning_rate': 0.06705803923434803, 'max_iter': 238, 'max_leaf_nodes': 23, 'min_samples_leaf': 40, 'l2_regularization': 2.6465738062598696}. Best is trial 22 with value: 0.9669605710429401.
# [I 2025-06-25 15:43:10,903] Trial 28 finished with value: 0.9669069732940455 and parameters: {'learning_rate': 0.13799766529002022, 'max_iter': 287, 'max_leaf_nodes': 35, 'min_samples_leaf': 45, 'l2_regularization': 4.807718623522728}. Best is trial 22 with value: 0.9669605710429401.
# [I 2025-06-25 15:43:19,681] Trial 29 finished with value: 0.9667729932834781 and parameters: {'learning_rate': 0.07513264075801723, 'max_iter': 270, 'max_leaf_nodes': 40, 'min_samples_leaf': 10, 'l2_regularization': 5.936286717233752}. Best is trial 22 with value: 0.9669605710429401.
# [I 2025-06-25 15:43:19,683] A new study created in memory with name: no-name-fa1e3842-6dc8-4f8e-9092-a20ebfc49269
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning:
andomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# === GradientBoost (2.2) ===
gb_best_22 = GradientBoostingClassifier(
    n_estimators=206,
    learning_rate=0.05000800859821229,
    max_depth=4,
    subsample=0.8430312263351016,
    max_features='sqrt',
    random_state=42
)
gb_best_22.fit(X_train, y_train)
y_pred_gb_22 = gb_best_22.predict(X_test)
print("=== GradientBoost (Skenario 2.2) ===")
print("Accuracy:", accuracy_score(y_test, y_pred_gb_22))
print(classification_report(y_test, y_pred_gb_22))

cm_gb_22 = confusion_matrix(y_test, y_pred_gb_22)
ConfusionMatrixDisplay(cm_gb_22, display_labels=[1, 2, 3]).plot(cmap='Blues')
plt.title("Confusion Matrix - GradientBoost (Skenario 2.2)")
plt.show()

# === HistGradientBoost (2.2) ===
hgb_best_22 = HistGradientBoostingClassifier(
    learning_rate=0.05726669460871793,
    max_iter=297,
    max_leaf_nodes=27,
    min_samples_leaf=40,
    l2_regularization=3.4870907436642504,
    random_state=42
)
hgb_best_22.fit(X_train, y_train)
y_pred_hgb_22 = hgb_best_22.predict(X_test)
print("\n=== HistGradientBoost (Skenario 2.2) ===")
print("Accuracy:", accuracy_score(y_test, y_pred_hgb_22))
print(classification_report(y_test, y_pred_hgb_22))

cm_hgb_22 = confusion_matrix(y_test, y_pred_hgb_22)
ConfusionMatrixDisplay(cm_hgb_22, display_labels=[1, 2, 3]).plot(cmap='Greens')
plt.title("Confusion Matrix - HistGradientBoost (Skenario 2.2)")
plt.show()

# === VotingClassifier (2.2) ===
voting_best_22 = VotingClassifier(estimators=[
    ('xgb', XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='mlogloss')),
    ('gb', GradientBoostingClassifier(random_state=42)),
    ('rf', RandomForestClassifier(random_state=42))
], voting='soft')

voting_best_22.fit(X_train, y_train)
y_pred_vote_22 = voting_best_22.predict(X_test)
print("\n=== VotingClassifier (Skenario 2.2) ===")
print("Accuracy:", accuracy_score(y_test, y_pred_vote_22))
print(classification_report(y_test, y_pred_vote_22))

cm_vote_22 = confusion_matrix(y_test, y_pred_vote_22)
ConfusionMatrixDisplay(cm_vote_22, display_labels=[1, 2, 3]).plot(cmap='Oranges')
plt.title("Confusion Matrix - VotingClassifier (Skenario 2.2)")
plt.show()
# Out:
# === GradientBoost (Skenario 2.2) ===
# Accuracy: 0.9661307609860664
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85       129
#            1       0.98      0.67      0.80       836
#            2       0.96      1.00      0.98      8365
#
#     accuracy                           0.97      9330
#    macro avg       0.98      0.81      0.88      9330
# weighted avg       0.97      0.97      0.96      9330
# === HistGradientBoost (Skenario 2.2) ===
# Accuracy: 0.9661307609860664
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85       129
#            1       0.98      0.67      0.80       836
#            2       0.96      1.00      0.98      8365
#
#     accuracy                           0.97      9330
#    macro avg       0.98      0.81      0.88      9330
# weighted avg       0.97      0.97      0.96      9330
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:57:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# === VotingClassifier (Skenario 2.2) ===
# Accuracy: 0.9664523043944265
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85       129
#            1       0.99      0.67      0.80       836
#            2       0.96      1.00      0.98      8365
#
#     accuracy                           0.97      9330
#    macro avg       0.99      0.80      0.88      9330
# weighted avg       0.97      0.97      0.96      9330
