# %%
import pandas as pd

df = pd.read_csv('train_road_safety.csv')

df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46649 entries, 0 to 46648
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   status                              44293 non-null  object
#  1   collision_index                     46649 non-null  object
#  2   collision_year                      44261 non-null  float64
#  3   collision_reference                 44343 non-null  object
#  4   vehicle_reference                   46649 non-null  float64
#  5   casualty_reference                  46649 non-null  float64
#  6   casualty_class                      46649 non-null  int64
#  7   sex_of_casualty                     44319 non-null  float64
#  8   age_of_casualty                     46649 non-null  int64
#  9   age_band_of_casualty                46649 non-null  int64
#  10  pedestrian_location                 46649 non-null  float64
#  11  pedestrian_movement                 46649 non-null  int64
#  12  car_passenger                       46649 non-null  int64
#  13  bus_or_coach_passenger              46649 non-null  int64
#  14  pedestrian_road_maintenance_worker  44314 non-null  float64
#  15  casualty_type                       46649 non-null  int64
#  16  casualty_home_area_type             44292 non-null  float64
#  17  casualty_imd_decile                 46649 non-null  int64
#  18  lsoa_of_casualty                    46649 non-null  object
#  19  enhanced_casualty_severity          46649 non-null  int64
#  20  casualty_severity                   46649 non-null  int64
# dtypes: float64(7), int64(10), object(4)
# memory usage: 7.5+ MB
#        collision_year  vehicle_reference  casualty_reference  casualty_class  \
# count         44261.0       46649.000000        46649.000000    46649.000000
# mean           2024.0           1.455616            1.353898        1.485520
# std               0.0           1.444068            1.267332        0.732898
# min            2024.0           0.462251            0.595506        1.000000
# 25%            2024.0           1.000000            1.000000        1.000000
# 50%            2024.0           1.000000            1.000000        1.000000
# 75%            2024.0           2.000000            1.000000        2.000000
# max            2024.0         203.000000          202.000000        3.000000
#
#        sex_of_casualty  age_of_casualty  age_band_of_casualty  \
# count     44319.000000     46649.000000          46649.000000
# mean          1.366637        37.102982              6.326502
# std           0.577406        19.826586              2.493991
# min          -1.000000        -1.000000             -1.000000
# 25%           1.000000        22.000000              5.000000
# 50%           1.000000        34.000000              6.000000
# 75%           2.000000        51.000000              8.000000
# max           9.000000       120.000000             11.000000
#
#        pedestrian_location  pedestrian_movement  car_passenger  \
# count         46649.000000         46649.000000   46649.000000
# mean              0.795227             0.657442       0.196574
# std               2.196648             2.047634       0.647400
# min              -1.000000            -1.000000      -1.000000
# 25%               0.000000             0.000000       0.000000
# 50%               0.000000             0.000000       0.000000
# 75%               0.000000             0.000000       0.000000
# max              10.334651             9.000000       9.000000
#
#        bus_or_coach_passenger  pedestrian_road_maintenance_worker  \
# count            46649.000000                        44314.000000
# mean                 0.058072                            0.031548
# std                  0.465305                            0.286917
# min                 -1.000000                           -1.000000
# 25%                  0.000000                            0.000000
# 50%                  0.000000                            0.000000
# 75%                  0.000000                            0.000000
# max                  9.000000                            2.000000
#
#        casualty_type  casualty_home_area_type  casualty_imd_decile  \
# count   46649.000000             44292.000000         46649.000000
# mean        9.314112                 0.993227             4.132307
# std        15.842578                 0.979042             3.286280
# min        -1.000000                -1.000000            -1.000000
# 25%         2.000000                 1.000000             2.000000
# 50%         9.000000                 1.000000             4.000000
# 75%         9.000000                 1.000000             7.000000
# max        98.000000                 3.000000            10.000000
#
#        enhanced_casualty_severity  casualty_severity
# count                46649.000000       46649.000000
# mean                     1.582220           2.882741
# std                      2.273239           0.362108
# min                     -1.000000           1.000000
# 25%                     -1.000000           3.000000
# 50%                      3.000000           3.000000
# 75%                      3.000000           3.000000
# max                      7.000000           3.000000

# %%
import numpy as np

df.drop(columns=["status", "collision_year", "collision_reference","lsoa_of_casualty","age_band_of_casualty","collision_index"], inplace=True)

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder

X = df.drop(columns=["casualty_severity"])
y = df["casualty_severity"] - 1  # klasifikasi 0, 1, 2

label_encoders = {}
for col in X.select_dtypes(include="object").columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))
    label_encoders[col] = le

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

from sklearn.ensemble import (
    RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier,
    BaggingClassifier, VotingClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier
)
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from xgboost import XGBClassifier

models = [
    ("LogisticRegression", LogisticRegression(max_iter=1000, random_state=42)),
    ("KNN", KNeighborsClassifier(n_neighbors=5)),
    ("GaussianNB", GaussianNB()),
    ("Decision Tree", DecisionTreeClassifier(random_state=42)),
    ("Random Forest", RandomForestClassifier(random_state=42)),
    ("ExtraTrees", ExtraTreesClassifier(random_state=42)),
    ("Bagging", BaggingClassifier(random_state=42)),
    ("AdaBoost", AdaBoostClassifier(random_state=42)),
    ("GradientBoost", GradientBoostingClassifier(random_state=42)),
    ("HistGradientBoost", HistGradientBoostingClassifier(random_state=42)),
    ("XGBoost", XGBClassifier(use_label_encoder=False, eval_metric="mlogloss", random_state=42)),
    ("LDA", LinearDiscriminantAnalysis()),
    ("QDA", QuadraticDiscriminantAnalysis())
]

# Tambahkan Voting Classifier
voting = VotingClassifier(estimators=[
    ("xgb", XGBClassifier(use_label_encoder=False, eval_metric="mlogloss", random_state=42)),
    ("gb", GradientBoostingClassifier(random_state=42)),
    ("rf", RandomForestClassifier(random_state=42))
], voting="soft")
models.append(("Voting", voting))

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
results = []

for name, model in models:
    try:
        scores = cross_val_score(model, X_train, y_train, scoring="accuracy", cv=cv, n_jobs=-1)
        results.append((name, scores.mean(), scores.std()))
    except Exception as e:
        print(f"{name} error: {e}")

results_df = pd.DataFrame(results, columns=["Algorithm", "CrossValMeans", "CrossValStd"])
results_df = results_df.sort_values(by="CrossValMeans", ascending=False).reset_index(drop=True)

print("Fitur yang digunakan:")
print(X.columns.tolist())
print(results_df)
# Out:
# LogisticRegression error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 1222, in fit
#     X, y = validate_data(
#            ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 2961, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1370, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
# KNN error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_classification.py", line 239, in fit
#     return self._fit(X, y)
#            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 478, in _fit
#     X, y = validate_data(
#            ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 2961, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1370, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# KNeighborsClassifier does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
# GaussianNB error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py", line 266, in fit
#     return self._partial_fit(
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py", line 426, in _partial_fit
#     X, y = validate_data(self, X, y, reset=first_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 2961, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1370, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# GaussianNB does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
# AdaBoost error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py", line 130, in fit
#     X, y = validate_data(
#            ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 2961, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1370, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# AdaBoostClassifier does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
# GradientBoost error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_gb.py", line 658, in fit
#     X, y = validate_data(
#            ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 2961, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1370, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# GradientBoostingClassifier does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
# LDA error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/discriminant_analysis.py", line 660, in fit
#     X, y = validate_data(
#            ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 2961, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1370, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# LinearDiscriminantAnalysis does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
# QDA error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/discriminant_analysis.py", line 986, in fit
#     X, y = validate_data(self, X, y)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 2961, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1370, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# QuadraticDiscriminantAnalysis does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
# Voting error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_voting.py", line 419, in fit
#     return super().fit(X, transformed_y, **fit_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_voting.py", line 100, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/joblib/parallel.py", line 1986, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/joblib/parallel.py", line 1914, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_base.py", line 39, in _fit_single_estimator
#     estimator.fit(X, y, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_gb.py", line 658, in fit
#     X, y = validate_data(
#            ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 2961, in validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1370, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 1107, in check_array
#     _assert_all_finite(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py", line 169, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains NaN.
# GradientBoostingClassifier does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#
# Fitur yang digunakan:
# ['vehicle_reference', 'casualty_reference', 'casualty_class', 'sex_of_casualty', 'age_of_casualty', 'pedestrian_location', 'pedestrian_movement', 'car_passenger', 'bus_or_coach_passenger', 'pedestrian_road_maintenance_worker', 'casualty_type', 'casualty_home_area_type', 'casualty_imd_decile', 'enhanced_casualty_severity']
#            Algorithm  CrossValMeans  CrossValStd
# 0  HistGradientBoost       0.966559     0.001178
# 1            XGBoost       0.965916     0.001466
# 2      Random Forest       0.960717     0.000658
# 3         ExtraTrees       0.956081     0.000800
# 4            Bagging       0.953455     0.001151
# 5      Decision Tree       0.936413     0.000906

# %%
# !pip install optuna
import optuna
from sklearn.model_selection import cross_val_score, StratifiedKFold

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# === HistGradientBoost ===
def objective_hgb(trial):
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "max_iter": trial.suggest_int("max_iter", 100, 300),
        "max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 10, 50),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 10, 50),
        "l2_regularization": trial.suggest_float("l2_regularization", 0.0, 10.0)
    }
    model = HistGradientBoostingClassifier(random_state=42, **params)
    return cross_val_score(model, X_train, y_train, scoring='accuracy', cv=kfold).mean()

study_hgb = optuna.create_study(direction="maximize")
study_hgb.optimize(objective_hgb, n_trials=30)

# === XGBoost ===
def objective_xgb(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 300),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0)
    }
    model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='mlogloss', **params)
    return cross_val_score(model, X_train, y_train, scoring='accuracy', cv=kfold).mean()

study_xgb = optuna.create_study(direction="maximize")
study_xgb.optimize(objective_xgb, n_trials=30)

# === Random Forest ===
def objective_rf(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 300),
        "max_depth": trial.suggest_int("max_depth", 5, 20),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10)
    }
    model = RandomForestClassifier(random_state=42, **params)
    return cross_val_score(model, X_train, y_train, scoring='accuracy', cv=kfold).mean()

study_rf = optuna.create_study(direction="maximize")
study_rf.optimize(objective_rf, n_trials=30)

# === Print Best Results ===
print("=== Best HistGradientBoost Parameters ===")
print(study_hgb.best_params)
print("Best Accuracy:", study_hgb.best_value)

print("\n=== Best XGBoost Parameters ===")
print(study_xgb.best_params)
print("Best Accuracy:", study_xgb.best_value)

print("\n=== Best Random Forest Parameters ===")
print(study_rf.best_params)
print("Best Accuracy:", study_rf.best_value)
# Out:
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 7.2 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 20.9 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.2 colorlog-6.9.0 optuna-4.4.0
# [I 2025-06-25 13:58:29,353] A new study created in memory with name: no-name-151fe793-9097-4e13-8b37-3e65b9468fc9
# [I 2025-06-25 13:58:33,774] Trial 0 finished with value: 0.966799784977091 and parameters: {'learning_rate': 0.20203552637306707, 'max_iter': 199, 'max_leaf_nodes': 43, 'min_samples_leaf': 38, 'l2_regularization': 7.824015952592492}. Best is trial 0 with value: 0.966799784977091.
# [I 2025-06-25 13:58:38,819] Trial 1 finished with value: 0.9668533791355683 and parameters: {'learning_rate': 0.10400570887171885, 'max_iter': 177, 'max_leaf_nodes': 10, 'min_samples_leaf': 41, 'l2_regularization': 6.010988176616409}. Best is trial 1 with value: 0.9668533791355683.
# [I 2025-06-25 13:58:43,828] Trial 2 finished with value: 0.9667461979994482 and parameters: {'learning_rate': 0.11571112875481981, 'max_iter': 142, 'max_leaf_nodes': 16, 'min_samples_leaf': 18, 'l2_regularization': 7.060097402273831}. Best is trial 1 with value: 0.9668533791355683.
# [I 2025-06-25 13:58:48,928] Trial 3 finished with value: 0.9666390132729109 and parameters: {'learning_rate': 0.10940307690727523, 'max_iter': 300, 'max_leaf_nodes': 32, 'min_samples_leaf': 44, 'l2_regularization': 0.4769174076865368}. Best is trial 1 with value: 0.9668533791355683.
# [I 2025-06-25 13:58:53,524] Trial 4 finished with value: 0.9666926002505537 and parameters: {'learning_rate': 0.13090560219480069, 'max_iter': 241, 'max_leaf_nodes': 31, 'min_samples_leaf': 25, 'l2_regularization': 5.682924357131051}. Best is trial 1 with value: 0.9668533791355683.
# [I 2025-06-25 13:58:58,210] Trial 5 finished with value: 0.9665318285463738 and parameters: {'learning_rate': 0.1776768285432208, 'max_iter': 122, 'max_leaf_nodes': 50, 'min_samples_leaf': 29, 'l2_regularization': 6.63852485332912}. Best is trial 1 with value: 0.9668533791355683.
# [I 2025-06-25 13:59:02,461] Trial 6 finished with value: 0.9663710568421937 and parameters: {'learning_rate': 0.1856841331474342, 'max_iter': 247, 'max_leaf_nodes': 43, 'min_samples_leaf': 23, 'l2_regularization': 3.9336408795690447}. Best is trial 1 with value: 0.9668533791355683.
# [I 2025-06-25 13:59:05,993] Trial 7 finished with value: 0.9664246474102536 and parameters: {'learning_rate': 0.20504572054852435, 'max_iter': 274, 'max_leaf_nodes': 48, 'min_samples_leaf': 40, 'l2_regularization': 2.625226235819632}. Best is trial 1 with value: 0.9668533791355683.
# [I 2025-06-25 13:59:09,571] Trial 8 finished with value: 0.9666926002505537 and parameters: {'learning_rate': 0.14999938970025173, 'max_iter': 299, 'max_leaf_nodes': 21, 'min_samples_leaf': 13, 'l2_regularization': 1.7593545320908566}. Best is trial 1 with value: 0.9668533791355683.
# [I 2025-06-25 13:59:13,919] Trial 9 finished with value: 0.9669337685780756 and parameters: {'learning_rate': 0.1363222306987621, 'max_iter': 278, 'max_leaf_nodes': 17, 'min_samples_leaf': 23, 'l2_regularization': 1.8970014600568508}. Best is trial 9 with value: 0.9669337685780756.
# [I 2025-06-25 13:59:26,842] Trial 10 finished with value: 0.9667730004643127 and parameters: {'learning_rate': 0.028876005981375408, 'max_iter': 226, 'max_leaf_nodes': 24, 'min_samples_leaf': 50, 'l2_regularization': 0.044775501358510716}. Best is trial 9 with value: 0.9669337685780756.
# [I 2025-06-25 13:59:34,484] Trial 11 finished with value: 0.9668265874419555 and parameters: {'learning_rate': 0.05893686743820711, 'max_iter': 173, 'max_leaf_nodes': 10, 'min_samples_leaf': 33, 'l2_regularization': 9.051156365133597}. Best is trial 9 with value: 0.9669337685780756.
# [I 2025-06-25 13:59:37,473] Trial 12 finished with value: 0.9667193991250009 and parameters: {'learning_rate': 0.2730276704049634, 'max_iter': 174, 'max_leaf_nodes': 10, 'min_samples_leaf': 34, 'l2_regularization': 4.360700571187838}. Best is trial 9 with value: 0.9669337685780756.
# [I 2025-06-25 13:59:43,188] Trial 13 finished with value: 0.9669069732940455 and parameters: {'learning_rate': 0.08067986659140623, 'max_iter': 197, 'max_leaf_nodes': 16, 'min_samples_leaf': 21, 'l2_regularization': 2.907600461185716}. Best is trial 9 with value: 0.9669337685780756.
# [I 2025-06-25 13:59:50,642] Trial 14 finished with value: 0.9667729932834781 and parameters: {'learning_rate': 0.06478616645047347, 'max_iter': 220, 'max_leaf_nodes': 19, 'min_samples_leaf': 10, 'l2_regularization': 2.6327921663193887}. Best is trial 9 with value: 0.9669337685780756.
# [I 2025-06-25 14:00:17,026] Trial 15 finished with value: 0.9666390168633281 and parameters: {'learning_rate': 0.015227929415333644, 'max_iter': 267, 'max_leaf_nodes': 27, 'min_samples_leaf': 19, 'l2_regularization': 1.7333793811223681}. Best is trial 9 with value: 0.9669337685780756.
# [I 2025-06-25 14:00:19,231] Trial 16 finished with value: 0.9667997885675084 and parameters: {'learning_rate': 0.2543340819261666, 'max_iter': 202, 'max_leaf_nodes': 16, 'min_samples_leaf': 26, 'l2_regularization': 3.549911009370428}. Best is trial 9 with value: 0.9669337685780756.
# [I 2025-06-25 14:00:25,294] Trial 17 finished with value: 0.9666390168633281 and parameters: {'learning_rate': 0.07343906996406141, 'max_iter': 105, 'max_leaf_nodes': 35, 'min_samples_leaf': 18, 'l2_regularization': 1.2423343996400678}. Best is trial 9 with value: 0.9669337685780756.
# [I 2025-06-25 14:00:28,827] Trial 18 finished with value: 0.9669605638621057 and parameters: {'learning_rate': 0.2375147661296217, 'max_iter': 268, 'max_leaf_nodes': 15, 'min_samples_leaf': 22, 'l2_regularization': 2.9761944691692346}. Best is trial 18 with value: 0.9669605638621057.
# [I 2025-06-25 14:00:31,784] Trial 19 finished with value: 0.9667193991250009 and parameters: {'learning_rate': 0.23065452239151513, 'max_iter': 267, 'max_leaf_nodes': 26, 'min_samples_leaf': 30, 'l2_regularization': 5.036046784007858}. Best is trial 18 with value: 0.9669605638621057.
# [I 2025-06-25 14:00:33,914] Trial 20 finished with value: 0.9663710640230281 and parameters: {'learning_rate': 0.2904876497797759, 'max_iter': 278, 'max_leaf_nodes': 20, 'min_samples_leaf': 14, 'l2_regularization': 1.085895456634466}. Best is trial 18 with value: 0.9669605638621057.
# [I 2025-06-25 14:00:37,613] Trial 21 finished with value: 0.966799784977091 and parameters: {'learning_rate': 0.14698852311932697, 'max_iter': 246, 'max_leaf_nodes': 15, 'min_samples_leaf': 22, 'l2_regularization': 2.9152118209725137}. Best is trial 18 with value: 0.9669605638621057.
# [I 2025-06-25 14:00:44,019] Trial 22 finished with value: 0.9667729968738955 and parameters: {'learning_rate': 0.07957225745464584, 'max_iter': 202, 'max_leaf_nodes': 15, 'min_samples_leaf': 21, 'l2_regularization': 3.2186177685036035}. Best is trial 18 with value: 0.9669605638621057.
# [I 2025-06-25 14:00:47,419] Trial 23 finished with value: 0.9666926074313882 and parameters: {'learning_rate': 0.16688802648768072, 'max_iter': 150, 'max_leaf_nodes': 22, 'min_samples_leaf': 27, 'l2_regularization': 2.1693223258510326}. Best is trial 18 with value: 0.9669605638621057.
# [I 2025-06-25 14:00:49,876] Trial 24 finished with value: 0.9668533827259858 and parameters: {'learning_rate': 0.2467482532680689, 'max_iter': 225, 'max_leaf_nodes': 13, 'min_samples_leaf': 14, 'l2_regularization': 4.148762075831458}. Best is trial 18 with value: 0.9669605638621057.
# [I 2025-06-25 14:00:54,819] Trial 25 finished with value: 0.9667461979994482 and parameters: {'learning_rate': 0.13126115928426546, 'max_iter': 254, 'max_leaf_nodes': 18, 'min_samples_leaf': 17, 'l2_regularization': 4.850533704542176}. Best is trial 18 with value: 0.9669605638621057.
# [I 2025-06-25 14:00:58,964] Trial 26 finished with value: 0.9669605638621057 and parameters: {'learning_rate': 0.09642898453964195, 'max_iter': 286, 'max_leaf_nodes': 13, 'min_samples_leaf': 25, 'l2_regularization': 1.3072135361746915}. Best is trial 18 with value: 0.9669605638621057.
# [I 2025-06-25 14:01:01,336] Trial 27 finished with value: 0.9670409568950301 and parameters: {'learning_rate': 0.21320068623410837, 'max_iter': 288, 'max_leaf_nodes': 12, 'min_samples_leaf': 32, 'l2_regularization': 0.8526226131210383}. Best is trial 27 with value: 0.9670409568950301.
# [I 2025-06-25 14:01:03,891] Trial 28 finished with value: 0.9668265802611211 and parameters: {'learning_rate': 0.22475043668918204, 'max_iter': 287, 'max_leaf_nodes': 13, 'min_samples_leaf': 33, 'l2_regularization': 0.831525238064533}. Best is trial 27 with value: 0.9670409568950301.
# [I 2025-06-25 14:01:08,306] Trial 29 finished with value: 0.9669069768844627 and parameters: {'learning_rate': 0.20130201766301575, 'max_iter': 259, 'max_leaf_nodes': 37, 'min_samples_leaf': 36, 'l2_regularization': 9.943243885307066}. Best is trial 27 with value: 0.9670409568950301.
# [I 2025-06-25 14:01:08,308] A new study created in memory with name: no-name-5e28f04e-4d90-47dd-b870-cdc5492afbd3
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:01:23,882] Trial 0 finished with value: 0.9650312459652686 and parameters: {'n_estimators': 204, 'learning_rate': 0.2597232152086407, 'max_depth': 5, 'subsample': 0.614187183046961, 'colsample_bytree': 0.9416837646311546}. Best is trial 0 with value: 0.9650312459652686.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:01:40,821] Trial 1 finished with value: 0.9654599992330869 and parameters: {'n_estimators': 229, 'learning_rate': 0.19159416531352946, 'max_depth': 5, 'subsample': 0.6604196081047794, 'colsample_bytree': 0.977500194290807}. Best is trial 1 with value: 0.9654599992330869.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:01:59,653] Trial 2 finished with value: 0.9662370768316262 and parameters: {'n_estimators': 273, 'learning_rate': 0.15505913483821931, 'max_depth': 4, 'subsample': 0.8506124636461478, 'colsample_bytree': 0.7823643407903007}. Best is trial 2 with value: 0.9662370768316262.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:01:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:02:10,594] Trial 3 finished with value: 0.9668801816004328 and parameters: {'n_estimators': 154, 'learning_rate': 0.031242706935081486, 'max_depth': 5, 'subsample': 0.705735317727163, 'colsample_bytree': 0.9421827490788904}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:02:26,712] Trial 4 finished with value: 0.9639594130615647 and parameters: {'n_estimators': 202, 'learning_rate': 0.2946852500952512, 'max_depth': 6, 'subsample': 0.8309677142951818, 'colsample_bytree': 0.7636173429603653}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:02:42,083] Trial 5 finished with value: 0.9665854262952681 and parameters: {'n_estimators': 262, 'learning_rate': 0.1202410950268892, 'max_depth': 3, 'subsample': 0.7080403099975094, 'colsample_bytree': 0.8445304236544939}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:02:57,946] Trial 6 finished with value: 0.9667194027154181 and parameters: {'n_estimators': 227, 'learning_rate': 0.1157937051087698, 'max_depth': 3, 'subsample': 0.6012818144305162, 'colsample_bytree': 0.829038343197668}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:02:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:03:14,155] Trial 7 finished with value: 0.9660494990721643 and parameters: {'n_estimators': 276, 'learning_rate': 0.255292340343509, 'max_depth': 3, 'subsample': 0.6338466814712852, 'colsample_bytree': 0.8144326704407069}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:03:37,315] Trial 8 finished with value: 0.9637718424829373 and parameters: {'n_estimators': 228, 'learning_rate': 0.13684857441627918, 'max_depth': 8, 'subsample': 0.7046697781004228, 'colsample_bytree': 0.8595957933193544}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:04:02,728] Trial 9 finished with value: 0.9617621530956793 and parameters: {'n_estimators': 215, 'learning_rate': 0.19080960785407938, 'max_depth': 10, 'subsample': 0.6149171922111722, 'colsample_bytree': 0.6717509691687745}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:04:14,153] Trial 10 finished with value: 0.9667193955345837 and parameters: {'n_estimators': 134, 'learning_rate': 0.03216570174373952, 'max_depth': 8, 'subsample': 0.9706658871017001, 'colsample_bytree': 0.911249474630645}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:04:24,340] Trial 11 finished with value: 0.9663174555028817 and parameters: {'n_estimators': 148, 'learning_rate': 0.01584969715821196, 'max_depth': 4, 'subsample': 0.7488068442760611, 'colsample_bytree': 0.6965303881631376}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:04:37,259] Trial 12 finished with value: 0.9667729932834783 and parameters: {'n_estimators': 165, 'learning_rate': 0.07154630458540735, 'max_depth': 6, 'subsample': 0.7672129703774578, 'colsample_bytree': 0.9034647226603058}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:04:50,426] Trial 13 finished with value: 0.9666925930697191 and parameters: {'n_estimators': 158, 'learning_rate': 0.06777852545919243, 'max_depth': 7, 'subsample': 0.7745160211609767, 'colsample_bytree': 0.901714939626486}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:04:57,328] Trial 14 finished with value: 0.9668801780100156 and parameters: {'n_estimators': 109, 'learning_rate': 0.0671232209896746, 'max_depth': 6, 'subsample': 0.899629906570086, 'colsample_bytree': 0.998280840260469}. Best is trial 3 with value: 0.9668801816004328.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:04:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:05:06,389] Trial 15 finished with value: 0.9669605674525228 and parameters: {'n_estimators': 103, 'learning_rate': 0.06469747036931245, 'max_depth': 7, 'subsample': 0.9027641128915461, 'colsample_bytree': 0.9816509446253471}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:05:16,228] Trial 16 finished with value: 0.9666926110218055 and parameters: {'n_estimators': 102, 'learning_rate': 0.042047905369589245, 'max_depth': 8, 'subsample': 0.9929797657665436, 'colsample_bytree': 0.6114382652617062}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:05:29,359] Trial 17 finished with value: 0.9655671552362861 and parameters: {'n_estimators': 130, 'learning_rate': 0.09255411698426344, 'max_depth': 10, 'subsample': 0.917533287443571, 'colsample_bytree': 0.9621632615714021}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:05:42,801] Trial 18 finished with value: 0.9666658049665238 and parameters: {'n_estimators': 182, 'learning_rate': 0.01093049382807798, 'max_depth': 7, 'subsample': 0.8923221091361062, 'colsample_bytree': 0.9369835408653318}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:05:54,348] Trial 19 finished with value: 0.9666390025016591 and parameters: {'n_estimators': 124, 'learning_rate': 0.050330458130666514, 'max_depth': 9, 'subsample': 0.8248292040145566, 'colsample_bytree': 0.8796289278245363}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:05:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:06:06,912] Trial 20 finished with value: 0.9667194027154181 and parameters: {'n_estimators': 177, 'learning_rate': 0.09262718576474682, 'max_depth': 5, 'subsample': 0.9430031026891168, 'colsample_bytree': 0.9979552038527455}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:06:13,336] Trial 21 finished with value: 0.9667997885675084 and parameters: {'n_estimators': 101, 'learning_rate': 0.07414827310941784, 'max_depth': 6, 'subsample': 0.8707907280407394, 'colsample_bytree': 0.9943799323628216}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:06:23,057] Trial 22 finished with value: 0.9667193991250009 and parameters: {'n_estimators': 115, 'learning_rate': 0.04305801999705982, 'max_depth': 7, 'subsample': 0.9060427843607793, 'colsample_bytree': 0.9430414551102168}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:06:33,371] Trial 23 finished with value: 0.9667461979994483 and parameters: {'n_estimators': 144, 'learning_rate': 0.09070447810626155, 'max_depth': 5, 'subsample': 0.9338589584153907, 'colsample_bytree': 0.9650839355151037}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:06:43,227] Trial 24 finished with value: 0.9665050332623437 and parameters: {'n_estimators': 112, 'learning_rate': 0.1712850602918859, 'max_depth': 6, 'subsample': 0.8100958614391377, 'colsample_bytree': 0.9220590606453103}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:06:52,928] Trial 25 finished with value: 0.9668265910323728 and parameters: {'n_estimators': 142, 'learning_rate': 0.056113675524134016, 'max_depth': 4, 'subsample': 0.8719473219412784, 'colsample_bytree': 0.9976816936820233}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:06:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:07:00,795] Trial 26 finished with value: 0.9667729968738955 and parameters: {'n_estimators': 119, 'learning_rate': 0.026019522401758532, 'max_depth': 7, 'subsample': 0.7181871914439132, 'colsample_bytree': 0.8816714142190826}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:07:19,510] Trial 27 finished with value: 0.9650044506812385 and parameters: {'n_estimators': 180, 'learning_rate': 0.11236943468086608, 'max_depth': 9, 'subsample': 0.965447663519523, 'colsample_bytree': 0.9664675485744665}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:07:31,518] Trial 28 finished with value: 0.9667194027154181 and parameters: {'n_estimators': 159, 'learning_rate': 0.0819437454976434, 'max_depth': 6, 'subsample': 0.789303551877813, 'colsample_bytree': 0.948228826563371}. Best is trial 15 with value: 0.9669605674525228.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-25 14:07:38,127] Trial 29 finished with value: 0.9666926074313882 and parameters: {'n_estimators': 103, 'learning_rate': 0.13828977162031442, 'max_depth': 5, 'subsample': 0.6534780682906127, 'colsample_bytree': 0.7478910242700465}. Best is trial 15 with value: 0.9669605674525228.
# [I 2025-06-25 14:07:38,132] A new study created in memory with name: no-name-17678f72-5073-44bc-ba63-4f92707f7dd2
# [I 2025-06-25 14:07:51,749] Trial 0 finished with value: 0.9563761358464531 and parameters: {'n_estimators': 229, 'max_depth': 6, 'max_features': 'log2', 'min_samples_split': 9}. Best is trial 0 with value: 0.9563761358464531.
# [I 2025-06-25 14:08:04,292] Trial 1 finished with value: 0.9660762764041081 and parameters: {'n_estimators': 129, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 7}. Best is trial 1 with value: 0.9660762764041081.
# [I 2025-06-25 14:08:21,246] Trial 2 finished with value: 0.9656207458043461 and parameters: {'n_estimators': 178, 'max_depth': 13, 'max_features': 'sqrt', 'min_samples_split': 10}. Best is trial 1 with value: 0.9660762764041081.
# [I 2025-06-25 14:08:30,539] Trial 3 finished with value: 0.9563761358464531 and parameters: {'n_estimators': 141, 'max_depth': 8, 'max_features': 'log2', 'min_samples_split': 3}. Best is trial 1 with value: 0.9660762764041081.
# [I 2025-06-25 14:08:42,320] Trial 4 finished with value: 0.9662102564146755 and parameters: {'n_estimators': 117, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 3}. Best is trial 4 with value: 0.9662102564146755.
# [I 2025-06-25 14:09:36,962] Trial 5 finished with value: 0.9664782272070618 and parameters: {'n_estimators': 298, 'max_depth': 11, 'max_features': None, 'min_samples_split': 4}. Best is trial 5 with value: 0.9664782272070618.
# [I 2025-06-25 14:09:54,816] Trial 6 finished with value: 0.9658351439807588 and parameters: {'n_estimators': 164, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 2}. Best is trial 5 with value: 0.9664782272070618.
# [I 2025-06-25 14:10:08,354] Trial 7 finished with value: 0.9568048711621848 and parameters: {'n_estimators': 167, 'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 9}. Best is trial 5 with value: 0.9664782272070618.
# [I 2025-06-25 14:10:31,994] Trial 8 finished with value: 0.9665050296719263 and parameters: {'n_estimators': 124, 'max_depth': 12, 'max_features': None, 'min_samples_split': 3}. Best is trial 8 with value: 0.9665050296719263.
# [I 2025-06-25 14:10:56,373] Trial 9 finished with value: 0.9662638685252389 and parameters: {'n_estimators': 267, 'max_depth': 13, 'max_features': 'sqrt', 'min_samples_split': 7}. Best is trial 8 with value: 0.9665050296719263.
# [I 2025-06-25 14:11:49,354] Trial 10 finished with value: 0.9652456154183433 and parameters: {'n_estimators': 217, 'max_depth': 19, 'max_features': None, 'min_samples_split': 5}. Best is trial 8 with value: 0.9665050296719263.
# [I 2025-06-25 14:12:39,988] Trial 11 finished with value: 0.9665854083431817 and parameters: {'n_estimators': 300, 'max_depth': 10, 'max_features': None, 'min_samples_split': 5}. Best is trial 11 with value: 0.9665854083431817.
# [I 2025-06-25 14:13:15,535] Trial 12 finished with value: 0.9668265802611209 and parameters: {'n_estimators': 254, 'max_depth': 7, 'max_features': None, 'min_samples_split': 5}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:13:45,213] Trial 13 finished with value: 0.9667729932834783 and parameters: {'n_estimators': 258, 'max_depth': 5, 'max_features': None, 'min_samples_split': 6}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:14:13,362] Trial 14 finished with value: 0.9667729932834783 and parameters: {'n_estimators': 245, 'max_depth': 5, 'max_features': None, 'min_samples_split': 6}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:14:50,014] Trial 15 finished with value: 0.9668265802611209 and parameters: {'n_estimators': 265, 'max_depth': 7, 'max_features': None, 'min_samples_split': 6}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:15:20,482] Trial 16 finished with value: 0.9667729789218091 and parameters: {'n_estimators': 199, 'max_depth': 8, 'max_features': None, 'min_samples_split': 7}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:16:01,034] Trial 17 finished with value: 0.9667997813866738 and parameters: {'n_estimators': 275, 'max_depth': 8, 'max_features': None, 'min_samples_split': 5}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:16:33,334] Trial 18 finished with value: 0.9667997813866738 and parameters: {'n_estimators': 237, 'max_depth': 7, 'max_features': None, 'min_samples_split': 8}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:17:06,888] Trial 19 finished with value: 0.9667193883537492 and parameters: {'n_estimators': 208, 'max_depth': 9, 'max_features': None, 'min_samples_split': 4}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:17:35,491] Trial 20 finished with value: 0.9663710496613589 and parameters: {'n_estimators': 281, 'max_depth': 17, 'max_features': 'log2', 'min_samples_split': 6}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:18:15,678] Trial 21 finished with value: 0.9667461908186137 and parameters: {'n_estimators': 270, 'max_depth': 8, 'max_features': None, 'min_samples_split': 5}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:18:51,790] Trial 22 finished with value: 0.9667997885675084 and parameters: {'n_estimators': 279, 'max_depth': 6, 'max_features': None, 'min_samples_split': 4}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:19:24,822] Trial 23 finished with value: 0.9667997885675084 and parameters: {'n_estimators': 250, 'max_depth': 6, 'max_features': None, 'min_samples_split': 4}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:19:57,964] Trial 24 finished with value: 0.9667194027154181 and parameters: {'n_estimators': 284, 'max_depth': 5, 'max_features': None, 'min_samples_split': 2}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:20:27,834] Trial 25 finished with value: 0.9667461979994482 and parameters: {'n_estimators': 229, 'max_depth': 6, 'max_features': None, 'min_samples_split': 4}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:21:04,011] Trial 26 finished with value: 0.9668265802611209 and parameters: {'n_estimators': 258, 'max_depth': 7, 'max_features': None, 'min_samples_split': 5}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:21:36,457] Trial 27 finished with value: 0.9666925858888845 and parameters: {'n_estimators': 192, 'max_depth': 10, 'max_features': None, 'min_samples_split': 7}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:22:12,374] Trial 28 finished with value: 0.9668265802611209 and parameters: {'n_estimators': 257, 'max_depth': 7, 'max_features': None, 'min_samples_split': 6}. Best is trial 12 with value: 0.9668265802611209.
# [I 2025-06-25 14:22:27,199] Trial 29 finished with value: 0.9563761358464531 and parameters: {'n_estimators': 228, 'max_depth': 7, 'max_features': 'log2', 'min_samples_split': 8}. Best is trial 12 with value: 0.9668265802611209.
# === Best HistGradientBoost Parameters ===
# {'learning_rate': 0.21320068623410837, 'max_iter': 288, 'max_leaf_nodes': 12, 'min_samples_leaf': 32, 'l2_regularization': 0.8526226131210383}
# Best Accuracy: 0.9670409568950301
#
# === Best XGBoost Parameters ===
# {'n_estimators': 103, 'learning_rate': 0.06469747036931245, 'max_depth': 7, 'subsample': 0.9027641128915461, 'colsample_bytree': 0.9816509446253471}
# Best Accuracy: 0.9669605674525228
#
# === Best Random Forest Parameters ===
# {'n_estimators': 254, 'max_depth': 7, 'max_features': None, 'min_samples_split': 5}
# Best Accuracy: 0.9668265802611209

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt

# === 1. HistGradientBoost ===
hgb_best = HistGradientBoostingClassifier(
    learning_rate=0.21320068623410837,
    max_iter=288,
    max_leaf_nodes=12,
    min_samples_leaf=32,
    l2_regularization=0.8526226131210383,
    random_state=42
)
hgb_best.fit(X_train, y_train)
y_pred_hgb = hgb_best.predict(X_test)

print("=== HistGradientBoost ===")
print("Accuracy:", accuracy_score(y_test, y_pred_hgb))
print(classification_report(y_test, y_pred_hgb))

cm_hgb = confusion_matrix(y_test, y_pred_hgb)
ConfusionMatrixDisplay(cm_hgb, display_labels=[1, 2, 3]).plot(cmap='Blues')
plt.title("Confusion Matrix - HistGradientBoost (Skenario 1.1)")
plt.show()

# === 2. XGBoost ===
xgb_best = XGBClassifier(
    n_estimators=103,
    learning_rate=0.06469747036931245,
    max_depth=7,
    subsample=0.9027641128915461,
    colsample_bytree=0.9816509446253471,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)
xgb_best.fit(X_train, y_train)
y_pred_xgb = xgb_best.predict(X_test)

print("\n=== XGBoost ===")
print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))

cm_xgb = confusion_matrix(y_test, y_pred_xgb)
ConfusionMatrixDisplay(cm_xgb, display_labels=[1, 2, 3]).plot(cmap='Oranges')
plt.title("Confusion Matrix - XGBoost (Skenario 1.1)")
plt.show()

# === 3. Random Forest ===
rf_best = RandomForestClassifier(
    n_estimators=254,
    max_depth=7,
    max_features=None,
    min_samples_split=5,
    random_state=42
)
rf_best.fit(X_train, y_train)
y_pred_rf = rf_best.predict(X_test)

print("\n=== Random Forest ===")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))

cm_rf = confusion_matrix(y_test, y_pred_rf)
ConfusionMatrixDisplay(cm_rf, display_labels=[1, 2, 3]).plot(cmap='Greens')
plt.title("Confusion Matrix - Random Forest (Skenario 1.1)")
plt.show()
# Out:
# === HistGradientBoost ===
# Accuracy: 0.9658092175777063
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85       129
#            1       0.98      0.67      0.80       836
#            2       0.96      1.00      0.98      8365
#
#     accuracy                           0.97      9330
#    macro avg       0.98      0.80      0.88      9330
# weighted avg       0.97      0.97      0.96      9330
# === XGBoost ===
# Accuracy: 0.9661307609860664
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85       129
#            1       0.98      0.67      0.80       836
#            2       0.96      1.00      0.98      8365
#
#     accuracy                           0.97      9330
#    macro avg       0.98      0.81      0.88      9330
# weighted avg       0.97      0.97      0.96      9330
# === Random Forest ===
# Accuracy: 0.9661307609860664
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85       129
#            1       0.98      0.67      0.80       836
#            2       0.96      1.00      0.98      8365
#
#     accuracy                           0.97      9330
#    macro avg       0.98      0.81      0.88      9330
# weighted avg       0.97      0.97      0.96      9330
